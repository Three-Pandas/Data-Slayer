# %%
# !pip install numpy pandas
import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: numpy in c:\users\sonnie\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\sonnie\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sonnie\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sonnie\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\sonnie\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install matplotlib seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: matplotlib in c:\users\sonnie\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: seaborn in c:\users\sonnie\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sonnie\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\sonnie\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\sonnie\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sonnie\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\sonnie\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Out:
# Requirement already satisfied: scikit-learn in c:\users\sonnie\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sonnie\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sonnie\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\sonnie\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sonnie\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)

# %%
df = pd.read_csv('train.csv')
df
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 0            1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 1            2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN
# 2            3     BMV               SUBCOMPACT            4.4       NaN
# 3            4     KIO              SUV - SMALL            NaN       4.0
# 4            5  BARUSU              MINICOMPACT            3.0       6.0
# ...        ...     ...                      ...            ...       ...
# 137136  137137     BMV               SUBCOMPACT             na       8.0
# 137137  137138   GONDA    STATION WAGON - SMALL            1.5       4.0
# 137138  137139  NIRRAN                 MID-SIZE            1.8       4.0
# 137139  137140  TOYOTI                  COMPACT            1.8       4.0
# 137140  137141  BARUSU                 MID-SIZE            2.5       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 0                A6         X   8.64 liters per 100 km
# 1                A6         E  27.27 liters per 100 km
# 2                M6         Z              0.17 L/10km
# 3               AS6         X            6.52 km per L
# 4       unspecified         Z            20.15 L/100km
# ...             ...       ...                      ...
# 137136          AS8         Z           33.71 L/100 km
# 137137           M6         X           15.41 km per L
# 137138           AV         X   2.99 liters per 100 km
# 137139           na         X            11.48 L/100km
# 137140          AV6         X   3.36 liters per 100 km
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)
# 0                 6.14 L/100 km        37.59 mpg Imp.                306.0
# 1       30.76 liters per 100 km        28.84 L/100 km                283.0
# 2        2.03 liters per 100 km                  zero                329.0
# 3                   1.59 L/10km                   NaN                270.0
# 4                   0.60 L/10km           1.38 L/10km                193.0
# ...                         ...                   ...                  ...
# 137136           12.99 km per L         4.54 km per L                275.0
# 137137            0.87 L/100 km        59.38 MPG (AS)                166.0
# 137138            8.38 L/100 km        52.19 mpg Imp.                181.0
# 137139         1275.84 mpg Imp.           0.64 L/10km                123.0
# 137140              0.28 L/10km        32.27 km per L                182.0
#
# [137141 rows x 11 columns]

# %%
from IPython.display import display

# Display the DataFrame
display(df)
# Out:
#             Id    Make            Vehicle Class Engine Size(L) Cylinders  \
# 0            1    FOLD  PICKUP TRUCK - STANDARD            3.5       6.0
# 1            2   CHEVO  PICKUP TRUCK - STANDARD            5.3       NaN
# 2            3     BMV               SUBCOMPACT            4.4       NaN
# 3            4     KIO              SUV - SMALL            NaN       4.0
# 4            5  BARUSU              MINICOMPACT            3.0       6.0
# ...        ...     ...                      ...            ...       ...
# 137136  137137     BMV               SUBCOMPACT             na       8.0
# 137137  137138   GONDA    STATION WAGON - SMALL            1.5       4.0
# 137138  137139  NIRRAN                 MID-SIZE            1.8       4.0
# 137139  137140  TOYOTI                  COMPACT            1.8       4.0
# 137140  137141  BARUSU                 MID-SIZE            2.5       4.0
#
#        Transmission Fuel Type    Fuel Consumption City  \
# 0                A6         X   8.64 liters per 100 km
# 1                A6         E  27.27 liters per 100 km
# 2                M6         Z              0.17 L/10km
# 3               AS6         X            6.52 km per L
# 4       unspecified         Z            20.15 L/100km
# ...             ...       ...                      ...
# 137136          AS8         Z           33.71 L/100 km
# 137137           M6         X           15.41 km per L
# 137138           AV         X   2.99 liters per 100 km
# 137139           na         X            11.48 L/100km
# 137140          AV6         X   3.36 liters per 100 km
#
#            Fuel Consumption Hwy Fuel Consumption Comb  CO2 Emissions(g/km)
# 0                 6.14 L/100 km        37.59 mpg Imp.                306.0
# 1       30.76 liters per 100 km        28.84 L/100 km                283.0
# 2        2.03 liters per 100 km                  zero                329.0
# 3                   1.59 L/10km                   NaN                270.0
# 4                   0.60 L/10km           1.38 L/10km                193.0
# ...                         ...                   ...                  ...
# 137136           12.99 km per L         4.54 km per L                275.0
# 137137            0.87 L/100 km        59.38 MPG (AS)                166.0
# 137138            8.38 L/100 km        52.19 mpg Imp.                181.0
# 137139         1275.84 mpg Imp.           0.64 L/10km                123.0
# 137140              0.28 L/10km        32.27 km per L                182.0
#
# [137141 rows x 11 columns]

# %%
# Check for null values in each column
null_counts = df.isnull().sum()

# Display the number of null values in each column
print("Null counts in each column:")
print(null_counts)
# Out:
# Null counts in each column:
# Id                           0
# Make                         0
# Vehicle Class             1325
# Engine Size(L)           16619
# Cylinders                14155
# Transmission              2605
# Fuel Type                 1855
# Fuel Consumption City     2422
# Fuel Consumption Hwy      2568
# Fuel Consumption Comb     2582
# CO2 Emissions(g/km)          0
# dtype: int64

# %%
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
