# %% [markdown]
# # The Three Pandas Notebook: Cyrill Adrian Wicaksono, Gregorius Samuel Hutahean, Gusti Faturrahman Rais

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
for column in df.columns:
    print(f"{column} has {df[column].nunique()} unique values")
# Out:
# Id has 54937 unique values
# Make has 21 unique values
# Vehicle Class has 23 unique values
# Engine Size(L) has 49 unique values
# Cylinders has 14 unique values
# Transmission has 32 unique values
# Fuel Type has 12 unique values
# Fuel Consumption City has 1791 unique values
# Fuel Consumption Hwy has 1234 unique values
# Fuel Consumption Comb has 9938 unique values
# CO2 Emissions(g/km) has 414 unique values

# %%
df.isnull().sum()
# Out:
# Id                          0
# Make                        0
# Vehicle Class             539
# Engine Size(L)           1393
# Cylinders                1198
# Transmission              410
# Fuel Type                 546
# Fuel Consumption City    1568
# Fuel Consumption Hwy     1701
# Fuel Consumption Comb    1674
# CO2 Emissions(g/km)         0
# dtype: int64

# %%
### Take a look of the unique values of each categorical column

# %%
df['Make'].unique(), df['Make'].value_counts()
# Out:
# (array(['MITSU', 'TOYOTI', 'MATSUDA', 'CHEVO', 'DOGE', 'BMV', 'LECUS',
#         'KIO', 'FOLD', 'JIPU', 'NIRRAN', 'CADILUXE', 'FOLKSWA', 'BARUSU',
#         'GONDA', 'LAND CRAWLER', 'RYUNDAI', 'TOLVO', 'FIAR', 'ASURA',
#         'LAMBOGI'], dtype=object),
#  FOLD            7233
#  CHEVO           6621
#  BMV             5934
#  TOYOTI          3750
#  NIRRAN          2929
#  JIPU            2868
#  DOGE            2830
#  KIO             2579
#  GONDA           2494
#  RYUNDAI         2426
#  FOLKSWA         2248
#  MATSUDA         2077
#  LECUS           2065
#  CADILUXE        1836
#  BARUSU          1510
#  TOLVO           1396
#  MITSU           1083
#  LAND CRAWLER     929
#  ASURA            848
#  FIAR             803
#  LAMBOGI          478
#  Name: Make, dtype: int64)

# %%
df['Vehicle Class'].unique(), df['Vehicle Class'].value_counts()
# Out:
# (array(['SUV - SMALL', 'PICKUP TRUCK - SMALL', 'COMPACT',
#         'VAN - PASSENGER', 'MID-SIZE', 'SUV - STANDARD',
#         'STATION WAGON - SMALL', 'FULL-SIZE', 'TWO-SEATER',
#         'PICKUP TRUCK - STANDARD', 'SUBCOMPACT', nan,
#         'STATION WAGON - MID-SIZE', 'MINICOMPACT', 'MINIVAN',
#         'not-available', 'not-recorded', 'SPECIAL PURPOSE VEHICLE',
#         'missing', 'unestablished', 'na', 'unknown', 'unspecified',
#         'VAN - CARGO'], dtype=object),
#  SUV - SMALL                 11050
#  COMPACT                      9102
#  MID-SIZE                     8383
#  SUV - STANDARD               4683
#  FULL-SIZE                    4037
#  PICKUP TRUCK - STANDARD      3820
#  SUBCOMPACT                   3591
#  STATION WAGON - SMALL        2331
#  TWO-SEATER                   1623
#  PICKUP TRUCK - SMALL         1324
#  MINIVAN                       695
#  MINICOMPACT                   668
#  SPECIAL PURPOSE VEHICLE       589
#  VAN - PASSENGER               483
#  not-recorded                  372
#  STATION WAGON - MID-SIZE      365
#  na                            220
#  not-available                 189
#  unspecified                   189
#  unknown                       188
#  unestablished                 187
#  missing                       167
#  VAN - CARGO                   142
#  Name: Vehicle Class, dtype: int64)

# %%
df['Engine Size(L)'].unique(), df['Engine Size(L)'].value_counts()
# Out:
# (array(['1.5', 'not-available', '2.0', 'unknown', '1.8', '2.4', '3.5',
#         '2.7', '1.6', 'na', '1.2', '2.5', '3.2', '5.0', '8.4', '1.4',
#         '3.8', 'unestablished', '6.2', nan, '4.4', '3.0', '3.6', '5.7',
#         '5.2', '6.4', '2.3', 'not-recorded', '3.3', '5.3', 'missing',
#         '6.5', '1.0', '4.0', '3.7', '1.3', 'unspecified', '4.6', '4.8',
#         '5.6', '2.8', '6.0', '4.2', '4.3', '2.2', '6.6', '5.4', '3.4',
#         '5.8', '6.8'], dtype=object),
#  2.0              10510
#  3.5               4837
#  2.5               3630
#  3.0               3477
#  3.6               3429
#  2.4               3130
#  1.6               2296
#  1.8               2017
#  1.4               1919
#  1.5               1568
#  5.0               1547
#  5.3               1433
#  4.4               1351
#  6.2               1229
#  not-recorded       980
#  3.3                798
#  2.7                753
#  5.7                750
#  3.7                590
#  unspecified        543
#  not-available      485
#  4.0                478
#  6.4                477
#  unknown            474
#  unestablished      473
#  2.3                472
#  missing            462
#  na                 454
#  3.2                363
#  4.6                332
#  5.2                279
#  4.3                256
#  1.2                256
#  5.6                223
#  3.8                222
#  6.5                205
#  6.0                157
#  2.8                155
#  1.0                147
#  1.3                 94
#  5.4                 74
#  6.6                 46
#  8.4                 40
#  3.4                 40
#  4.8                 39
#  4.2                 25
#  2.2                 11
#  5.8                 10
#  6.8                  8
#  Name: Engine Size(L), dtype: int64)

# %%
df['Transmission'].unique(), df['Transmission'].value_counts()
# Out:
# (array(['AV8', 'A5', 'AS6', 'A6', 'M6', 'M5', 'A9', 'AS8', 'AV', 'AM6',
#         'AS10', 'A8', 'AS9', 'unestablished', 'AM8', 'AM7', 'AV7', 'A4',
#         'not-recorded', 'AV6', 'missing', 'unspecified', 'AV10', 'AS5',
#         'M7', 'A10', 'na', 'AS7', 'not-available', 'unknown', nan, 'A7',
#         'AM9'], dtype=object),
#  AS6              12236
#  AS8               8335
#  M6                7697
#  A6                5244
#  AV                3163
#  A8                2764
#  M5                2081
#  AS10              1848
#  AM7               1473
#  A9                1452
#  AV6               1230
#  AV7               1163
#  AM6               1046
#  A5                 928
#  AS9                673
#  A4                 576
#  AV8                352
#  AS7                308
#  AS5                281
#  not-recorded       253
#  A10                156
#  AM8                153
#  na                 147
#  missing            145
#  not-available      137
#  AV10               135
#  unspecified        133
#  unestablished      129
#  unknown            129
#  M7                 107
#  AM9                 33
#  A7                  20
#  Name: Transmission, dtype: int64)

# %%
df['Fuel Type'].unique(), df['Fuel Type'].value_counts()
# Out:
# (array(['X', 'Z', nan, 'E', 'missing', 'not-recorded', 'not-available',
#         'D', 'unspecified', 'unknown', 'na', 'unestablished', 'N'],
#        dtype=object),
#  X                33897
#  Z                15307
#  E                 2680
#  D                 1102
#  not-recorded       330
#  unspecified        214
#  unknown            189
#  unestablished      170
#  missing            168
#  na                 163
#  not-available      162
#  N                    9
#  Name: Fuel Type, dtype: int64)

# %%
df['Cylinders'].unique(), df['Cylinders'].value_counts()
# Out:
# (array(['4.0', '6.0', '8.0', 'unknown', 'na', '3.0', '10.0',
#         'not-recorded', 'unspecified', '12.0', nan, '5.0', 'missing',
#         'not-available', 'unestablished'], dtype=object),
#  4.0              26391
#  6.0              15088
#  8.0               7831
#  not-recorded       819
#  missing            441
#  unestablished      431
#  unspecified        423
#  na                 409
#  unknown            403
#  not-available      399
#  3.0                348
#  12.0               273
#  10.0               267
#  5.0                216
#  Name: Cylinders, dtype: int64)

# %% [markdown]
# # Handles Categorical Data Missing Values
# ### Create a rule based system to try to predict the missing values for the Categorical Features

# %% [markdown]
# ## Vehicle Class
# Basis: assumption that one brand of car tends to create one vehicle type more than the other. Example: Lamborgini creates more two seater than other Vehicle Class (like PICKUP TRUCK, etc). Hence it is reasonable to predict the missing values with the most 'popular' car type produced by its brand

# %%
cat_columns =[column for column in df.columns if df[column].nunique() < 100]
cat = pd.DataFrame(df[cat_columns])

cat.head()
# Out:
#       Make         Vehicle Class Engine Size(L) Cylinders Transmission  \
# 0    MITSU           SUV - SMALL            1.5       4.0          AV8
# 1   TOYOTI  PICKUP TRUCK - SMALL  not-available       6.0           A5
# 2  MATSUDA               COMPACT            2.0       4.0          AS6
# 3    CHEVO       VAN - PASSENGER        unknown       8.0           A6
# 4   TOYOTI               COMPACT            1.8       4.0           M6
#
#   Fuel Type
# 0         X
# 1         X
# 2         X
# 3         X
# 4         X

# %%
cat.isnull().sum()
# Out:
# Make                 0
# Vehicle Class      539
# Engine Size(L)    1393
# Cylinders         1198
# Transmission       410
# Fuel Type          546
# dtype: int64

# %% [markdown]
# Question: what is the maximum vehicle class category per car manufacturer

# %%
grouped = cat.groupby(['Make', 'Vehicle Class'])['Vehicle Class'].count()
max_vc_per_make = grouped.groupby('Make').idxmax()

#Test the result
max_vc_per_make['CHEVO']
# Out:
# ('CHEVO', 'PICKUP TRUCK - STANDARD')

# %%
#There are these many missing values inside the Vehicle class 
cat['Vehicle Class'].isnull().sum()
# Out:
# 539

# %%
def fill_vc(make, vc):
    if pd.isnull(vc):
        return max_vc_per_make[make][1]
    else:
        return vc 

cat['Vehicle Class'] = cat.apply(lambda x: fill_vc(x['Make'], x['Vehicle Class']), axis=1)

# %%
cat['Vehicle Class'].isnull().sum()
# Out:
# 0

# %%
print(cat.columns)
# Out:
# Index(['Make', 'Vehicle Class', 'Engine Size(L)', 'Cylinders', 'Transmission',
#        'Fuel Type'],
#       dtype='object')

# %% [markdown]
# ### Fuel Type
# I think it is common sense to say that a Vehicle Class with the same brand are more likely to have the same Fuel Type. Grouped the fuel type data based on Make and Vehicle Class, then choose
# the definite fuel type that is possible between the set

# %%
cat['Fuel Type'].isnull().sum()
# Out:
# 546

# %%
import random

grouped_fuel_type = cat.groupby(['Make', 'Vehicle Class'])['Fuel Type'].unique()

def fill_ft(make, vc, ft):
    fuel_types_per_mvc = list(set(grouped_fuel_type[make][vc]) &  set(['X', 'Z', 'E', 'D', 'N']))
    if pd.isnull(ft):
        return random.choice(fuel_types_per_mvc)
    else:
        return ft
    
cat['Fuel Type'] = cat.apply(lambda x: fill_ft(x['Make'], x['Vehicle Class'], x['Fuel Type']), axis=1)

# %%
cat['Fuel Type'].isnull().sum()
# Out:
# 0

# %%
print(cat.columns)
# Out:
# Index(['Make', 'Vehicle Class', 'Engine Size(L)', 'Cylinders', 'Transmission',
#        'Fuel Type'],
#       dtype='object')

# %% [markdown]
# ### Engine Size and Cylinders
# The underlying basis of the rule based is that engine size and cylinder have a strong correlation, hence we can fill the missing values of one value with respect to the other

# %%
grouped = pd.DataFrame(cat[['Engine Size(L)', 'Cylinders', 'Transmission']])

# %%
def change_to_float(x):
    try:
        return float(x) 
    except ValueError:
        return 0.0
    


cat['Engine Size(L)'] = cat['Engine Size(L)'].apply(change_to_float)
cat['Cylinders'] = cat['Cylinders'].apply(change_to_float)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
grouped_by_es = cat.groupby(['Engine Size(L)', 'Cylinders'])['Cylinders'].count()
max_cyl_per_es = grouped_by_es.groupby('Engine Size(L)').idxmax()

max_cyl_per_es
# Out:
# Engine Size(L)
# 0.0     (0.0, 4.0)
# 1.0     (1.0, 3.0)
# 1.2     (1.2, 3.0)
# 1.3     (1.3, 4.0)
# 1.4     (1.4, 4.0)
# 1.5     (1.5, 4.0)
# 1.6     (1.6, 4.0)
# 1.8     (1.8, 4.0)
# 2.0     (2.0, 4.0)
# 2.2     (2.2, 4.0)
# 2.3     (2.3, 4.0)
# 2.4     (2.4, 4.0)
# 2.5     (2.5, 4.0)
# 2.7     (2.7, 6.0)
# 2.8     (2.8, 4.0)
# 3.0     (3.0, 6.0)
# 3.2     (3.2, 6.0)
# 3.3     (3.3, 6.0)
# 3.4     (3.4, 6.0)
# 3.5     (3.5, 6.0)
# 3.6     (3.6, 6.0)
# 3.7     (3.7, 6.0)
# 3.8     (3.8, 6.0)
# 4.0     (4.0, 6.0)
# 4.2     (4.2, 8.0)
# 4.3     (4.3, 6.0)
# 4.4     (4.4, 8.0)
# 4.6     (4.6, 8.0)
# 4.8     (4.8, 8.0)
# 5.0     (5.0, 8.0)
# 5.2    (5.2, 10.0)
# 5.3     (5.3, 8.0)
# 5.4     (5.4, 8.0)
# 5.6     (5.6, 8.0)
# 5.7     (5.7, 8.0)
# 5.8     (5.8, 8.0)
# 6.0     (6.0, 8.0)
# 6.2     (6.2, 8.0)
# 6.4     (6.4, 8.0)
# 6.5    (6.5, 12.0)
# 6.6    (6.6, 12.0)
# 6.8    (6.8, 10.0)
# 8.4    (8.4, 10.0)
# Name: Cylinders, dtype: object

# %%
grouped = cat.groupby(['Cylinders', 'Engine Size(L)'])['Engine Size(L)'].count()
max_es_per_cyl= grouped.groupby('Cylinders').idxmax()

max_es_per_cyl
# Out:
# Cylinders
# 0.0      (0.0, 2.0)
# 3.0      (3.0, 1.2)
# 4.0      (4.0, 2.0)
# 5.0      (5.0, 2.5)
# 6.0      (6.0, 3.5)
# 8.0      (8.0, 5.0)
# 10.0    (10.0, 5.2)
# 12.0    (12.0, 6.5)
# Name: Engine Size(L), dtype: object

# %%
cat[['Engine Size(L)', 'Cylinders']].isnull().sum(), cat['Engine Size(L)'].unique(), cat['Cylinders'].unique()
# Out:
# (Engine Size(L)    1393
#  Cylinders         1198
#  dtype: int64,
#  array([1.5, 0. , 2. , 1.8, 2.4, 3.5, 2.7, 1.6, 1.2, 2.5, 3.2, 5. , 8.4,
#         1.4, 3.8, 6.2, nan, 4.4, 3. , 3.6, 5.7, 5.2, 6.4, 2.3, 3.3, 5.3,
#         6.5, 1. , 4. , 3.7, 1.3, 4.6, 4.8, 5.6, 2.8, 6. , 4.2, 4.3, 2.2,
#         6.6, 5.4, 3.4, 5.8, 6.8]),
#  array([ 4.,  6.,  8.,  0.,  3., 10., 12., nan,  5.]))

# %%
def fill_es(cyl, es):
    if pd.isnull(es):
        if pd.isnull(cyl):
            return max_es_per_cyl[0.0][1]
        return max_es_per_cyl[cyl][1]
    else:
        return es
    
def fill_cyl(es, cyl):
    if pd.isnull(cyl):
        if pd.isnull(es):
            return max_cyl_per_es[0.0][1]
        return max_cyl_per_es[es][1]
    else:
        return cyl

    
cat['Engine Size(L)'] = cat.apply(lambda x: fill_es(x['Cylinders'], x['Engine Size(L)']), axis=1)
cat['Cylinders'] = cat.apply(lambda x: fill_cyl(x['Engine Size(L)'], x['Cylinders']), axis=1)

# %%
cat[['Engine Size(L)', 'Cylinders']].isnull().sum()
# Out:
# Engine Size(L)    0
# Cylinders         0
# dtype: int64

# %% [markdown]
# ### Transmission
# Encode every other categorical variable and see what is the variable that have the biggest correlation to Transmission (no high correlation). Just convert to 0 to the NaN values along with the other 'uspecified' and friends entry

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54937 entries, 0 to 54936
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Make            54937 non-null  object
#  1   Vehicle Class   54937 non-null  object
#  2   Engine Size(L)  54937 non-null  float64
#  3   Cylinders       54937 non-null  float64
#  4   Transmission    54527 non-null  object
#  5   Fuel Type       54937 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 2.5+ MB

# %%
#Create list of unique value of each categories

unique_vclass = ['PICKUP TRUCK - STANDARD', 'SUBCOMPACT', 'SUV - SMALL',
        'MINICOMPACT', 'COMPACT', 'FULL-SIZE', 'SUV - STANDARD', 'MINIVAN',
        'STATION WAGON - SMALL', 'PICKUP TRUCK - SMALL',
        'TWO-SEATER', 'STATION WAGON - MID-SIZE', 'MID-SIZE',
        'SPECIAL PURPOSE VEHICLE', 'VAN - PASSENGER', 'VAN - CARGO']

unique_make = ['FOLD', 'CHEVO', 'BMV', 'KIO', 'BARUSU', 'LECUS', 'GONDA',
        'LAND CRAWLER', 'FOLKSWA', 'TOYOTI', 'JIPU', 'TOLVO', 'ASURA',
        'NIRRAN', 'FIAR', 'DOGE', 'CADILUXE', 'MATSUDA', 'MITSU',
        'RYUNDAI', 'LAMBOGI']

unique_ftype = ['X', 'E', 'Z', 'D', 'N']

unique_trans = ['A6', 'M6', 'AS6', 'AV7', 'AS8',
        'A9', 'AV', 'AV8', 'M5', 'A8', 'AV6', 'AS10',
        'AM7', 'A4', 'A5', 'AS7', 'AM6', 'AS5',
        'na', 'AS9', '-1', 'AM9', 'AV10', 'AM8', 'M7',
        'A10', 'A7']

cat.head()
# Out:
#       Make         Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0    MITSU           SUV - SMALL             1.5        4.0          AV8
# 1   TOYOTI  PICKUP TRUCK - SMALL             0.0        6.0           A5
# 2  MATSUDA               COMPACT             2.0        4.0          AS6
# 3    CHEVO       VAN - PASSENGER             0.0        8.0           A6
# 4   TOYOTI               COMPACT             1.8        4.0           M6
#
#   Fuel Type
# 0         X
# 1         X
# 2         X
# 3         X
# 4         X

# %%
def encode_categorical(input, list):
    if input in list:
        return float(list.index(input))
    else:
        return -1.0

# %%
cat['Vehicle Class'] = cat['Vehicle Class'].apply(lambda x: encode_categorical(x, unique_vclass))
cat['Fuel Type'] = cat['Fuel Type'].apply(lambda x: encode_categorical(x, unique_ftype))
cat['Make'] = cat['Make'].apply(lambda x: encode_categorical(x, unique_make))
cat['Transmission'] = cat['Transmission'].apply(lambda x: encode_categorical(x, unique_trans))

cat.head()
# Out:
#    Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission  Fuel Type
# 0  18.0            2.0             1.5        4.0           7.0        0.0
# 1   9.0            9.0             0.0        6.0          14.0        0.0
# 2  17.0            4.0             2.0        4.0           2.0        0.0
# 3   1.0           14.0             0.0        8.0           0.0        0.0
# 4   9.0            4.0             1.8        4.0           1.0        0.0

# %%
cat['Make'].nunique()
# Out:
# 21

# %%
df['Make'] = cat['Make']
df['Vehicle Class'] = cat['Vehicle Class']
df['Engine Size(L)'] = cat['Engine Size(L)']
df['Transmission'] = cat['Transmission']
df['Fuel Type'] = cat['Fuel Type']
df['Cylinders'] = cat['Cylinders']

# %%
df.head(), df.isnull().sum()
# Out:
# (   Id  Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
#  0   1  18.0            2.0             1.5        4.0           7.0
#  1   2   9.0            9.0             0.0        6.0          14.0
#  2   3  17.0            4.0             2.0        4.0           2.0
#  3   4   1.0           14.0             0.0        8.0           0.0
#  4   5   9.0            4.0             1.8        4.0           1.0
#
#     Fuel Type Fuel Consumption City     Fuel Consumption Hwy  \
#  0        0.0             8.40 km/L              0.72 L/10km
#  1        0.0         7.25 km per L             9.70 L/100km
#  2        0.0             9.80 km/L           38.70 mpg Imp.
#  3        0.0           1.73 L/10km  11.70 liters per 100 km
#  4        0.0          8.10 L/100km           35.76 mpg Imp.
#
#       Fuel Consumption Comb  CO2 Emissions(g/km)
#  0              0.98 L/10km                  208
#  1            11.96 L/100km                  325
#  2           31.76 mpg Imp.                  170
#  3  14.78 liters per 100 km                  362
#  4   8.01 liters per 100 km                  180  ,
#  Id                          0
#  Make                        0
#  Vehicle Class               0
#  Engine Size(L)              0
#  Cylinders                   0
#  Transmission                0
#  Fuel Type                   0
#  Fuel Consumption City    1568
#  Fuel Consumption Hwy     1701
#  Fuel Consumption Comb    1674
#  CO2 Emissions(g/km)         0
#  dtype: int64)

# %% [markdown]
# # Handles Numerical Values

# %%
import re
def recognize_format_fuelX(input_data):
    types_counter = []


    mpg_to_l_per_100km = 235.214583
    l_per_10km_to_l_per_100km = 10

    for val in input_data:
        if isinstance(val, str):
            if re.search(r'(L/100km|L/100 km|liters per 100 km)$', val):
                value = float(re.search(r'\d+.\d+', val).group())
                print(value)
                if value != 0:  # Avoid division by zero
                    types_counter.append(100 / value)
                else:
                    types_counter.append(np.nan)

            elif re.search(r'(km/L|km per L)$', val):
                value = float(re.search(r'\d+.\d+', val).group())
                types_counter.append(value * 100)

            elif re.search(r'(mpg Imp.|MPG (AS))$', val, re.IGNORECASE):
                print("enter", val)
                value = float(re.search(r'\d+.\d+', val).group())
                print("enter", val, value)
                if value != 0: 
                    types_counter.append(mpg_to_l_per_100km / value)
                else:
                    types_counter.append(np.nan)
            elif re.search(r'(\d+(.\d+)?\sL/10\skm)$', val):
                value = float(re.search(r'\d+(.\d+)?', val).group())
                if value != 0:
                    types_counter.append(1000 / (value / l_per_10km_to_l_per_100km))
                else:
                    types_counter.append(np.nan)
            elif val == 'zero':
                types_counter.append(0)

            else:
                types_counter.append(np.nan)

        else:
            types_counter.append(np.nan)

    return types_counter
fuel_consumption_column = df['Fuel Consumption City']
converted_data = recognize_format_fuelX(fuel_consumption_column)
fuel_consumption_column = df['Fuel Consumption Hwy']
converted_data1 = recognize_format_fuelX(fuel_consumption_column)
fuel_consumption_column = df['Fuel Consumption Comb']
converted_data2 = recognize_format_fuelX(fuel_consumption_column)

df['Fuel Consumption City'] = converted_data
df['Fuel Consumption Hwy'] = converted_data1
df['Fuel Consumption Comb'] = converted_data2
df.dropna(subset=['Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb'], how='all', inplace=True)
# Out:
# 8.1
# 13.9
# 12.3
# 9.5
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 15.9
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 11.4
# 19.9
# 14.6
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 9.1
# 14.3
# 14.0
# 8.8
# 13.9
# 12.1
# 16.6
# 12.5
# enter 15.78 mpg Imp.
# enter 15.78 mpg Imp. 15.78
# enter 17.02 mpg Imp.
# enter 17.02 mpg Imp. 17.02
# 20.6
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# 8.5
# 15.6
# 7.2
# enter 11.92 mpg Imp.
# enter 11.92 mpg Imp. 11.92
# 10.0
# 19.0
# 9.8
# 14.7
# 16.7
# 12.4
# 11.5
# enter 9.58 mpg Imp.
# enter 9.58 mpg Imp. 9.58
# 12.8
# 19.0
# 13.6
# 12.7
# 9.0
# enter 22.07 mpg Imp.
# enter 22.07 mpg Imp. 22.07
# 15.8
# 19.4
# 12.2
# 12.5
# 9.0
# 11.6
# 9.1
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 21.0
# 8.9
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 8.4
# 10.3
# 9.1
# 17.9
# 10.1
# 12.1
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 16.1
# enter 15.11 mpg Imp.
# enter 15.11 mpg Imp. 15.11
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# 17.3
# 12.7
# 14.0
# 11.1
# 18.2
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 5.1
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 14.9
# 9.2
# 10.4
# 10.2
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 15.5
# 8.3
# 9.8
# 11.8
# 14.6
# 12.0
# 10.2
# 16.0
# 13.0
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# 9.3
# 19.7
# 20.4
# 12.4
# 12.1
# 12.8
# 10.7
# 11.9
# enter 18.58 mpg Imp.
# enter 18.58 mpg Imp. 18.58
# enter 20.18 mpg Imp.
# enter 20.18 mpg Imp. 20.18
# 20.1
# enter 18.71 mpg Imp.
# enter 18.71 mpg Imp. 18.71
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 9.35 mpg Imp.
# enter 9.35 mpg Imp. 9.35
# 9.3
# enter 45.56 mpg Imp.
# enter 45.56 mpg Imp. 45.56
# enter 12.78 mpg Imp.
# enter 12.78 mpg Imp. 12.78
# 18.2
# 10.5
# 4.2
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# 12.8
# enter 16.52 mpg Imp.
# enter 16.52 mpg Imp. 16.52
# 14.7
# 19.4
# 11.8
# 16.4
# 4.2
# 12.1
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 15.8
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 11.9
# 30.5
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 15.9
# 12.4
# 12.6
# 10.2
# 11.4
# 13.1
# 17.5
# enter 33.23 mpg Imp.
# enter 33.23 mpg Imp. 33.23
# 14.7
# 11.2
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 10.5
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 15.3
# 15.4
# 12.1
# 7.8
# 10.1
# 14.6
# enter 15.52 mpg Imp.
# enter 15.52 mpg Imp. 15.52
# 21.1
# 10.3
# 9.8
# enter 36.22 mpg Imp.
# enter 36.22 mpg Imp. 36.22
# 12.6
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# 16.5
# 5.8
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 11.1
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 9.5
# 12.0
# 13.5
# 17.7
# 8.3
# 19.9
# enter 17.77 mpg Imp.
# enter 17.77 mpg Imp. 17.77
# 14.7
# enter 20.03 mpg Imp.
# enter 20.03 mpg Imp. 20.03
# 21.4
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 13.9
# 12.5
# enter 15.19 mpg Imp.
# enter 15.19 mpg Imp. 15.19
# 5.6
# 12.6
# 17.2
# 8.6
# 25.9
# 9.5
# 10.2
# 16.4
# 10.4
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 7.5
# 8.0
# enter 12.50 mpg Imp.
# enter 12.50 mpg Imp. 12.5
# 12.2
# 15.0
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 9.4
# 10.3
# 11.2
# 15.7
# 14.6
# 10.0
# 4.5
# 6.2
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 18.1
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 25.8
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# 17.0
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 11.5
# 6.4
# 10.4
# 9.1
# 9.9
# 16.5
# 15.6
# 4.5
# 13.3
# 18.2
# 15.6
# 4.2
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 13.5
# 11.8
# 10.0
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 13.1
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 14.6
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 8.9
# 4.4
# 13.8
# 4.9
# 4.2
# 12.5
# 17.2
# 17.2
# 7.5
# 6.5
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# 17.8
# 14.7
# 16.8
# 14.9
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 11.4
# 11.3
# 10.2
# 15.0
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 9.3
# 9.0
# 14.5
# 10.3
# 10.1
# 9.8
# 17.2
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 11.8
# 11.3
# 17.0
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 10.5
# 8.0
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# 10.2
# 11.0
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 17.7
# 14.0
# 10.6
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 11.4
# 26.2
# 10.2
# 20.7
# 9.4
# enter 40.94 mpg Imp.
# enter 40.94 mpg Imp. 40.94
# 12.6
# 11.7
# 21.2
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 12.0
# 18.7
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# enter 20.32 mpg Imp.
# enter 20.32 mpg Imp. 20.32
# enter 20.18 mpg Imp.
# enter 20.18 mpg Imp. 20.18
# 19.5
# 17.2
# 14.8
# 9.6
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 12.9
# 17.2
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 12.2
# 8.7
# enter 21.73 mpg Imp.
# enter 21.73 mpg Imp. 21.73
# 12.8
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 11.8
# 13.2
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# enter 16.52 mpg Imp.
# enter 16.52 mpg Imp. 16.52
# 12.3
# 18.4
# enter 48.70 mpg Imp.
# enter 48.70 mpg Imp. 48.7
# 15.7
# 13.8
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# 9.2
# enter 16.05 mpg Imp.
# enter 16.05 mpg Imp. 16.05
# 17.3
# 9.7
# 11.8
# 9.5
# 8.9
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 6.3
# 11.1
# 9.1
# 10.5
# 7.7
# 10.3
# 10.0
# 10.5
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 13.0
# 10.0
# 8.7
# enter 15.69 mpg Imp.
# enter 15.69 mpg Imp. 15.69
# 13.5
# 9.8
# 10.2
# 9.6
# 9.0
# 21.7
# 13.6
# 15.5
# 7.6
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# 11.8
# 11.3
# 8.2
# 10.8
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 17.9
# 16.5
# 22.2
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 13.5
# 11.8
# 15.3
# 11.6
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# 16.0
# 12.6
# 13.2
# 10.2
# 9.2
# enter 10.35 mpg Imp.
# enter 10.35 mpg Imp. 10.35
# 10.9
# 9.5
# 17.7
# 8.8
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 8.7
# 8.2
# 11.3
# 8.6
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 17.7
# enter 20.03 mpg Imp.
# enter 20.03 mpg Imp. 20.03
# 18.3
# 10.5
# 17.2
# 22.3
# 9.4
# 17.0
# 8.4
# 9.6
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 13.2
# 5.7
# 18.3
# 19.5
# 11.5
# 10.5
# 18.2
# enter 13.32 mpg Imp.
# enter 13.32 mpg Imp. 13.32
# 11.2
# 16.5
# 19.0
# 8.4
# 12.5
# 17.7
# 13.3
# 13.6
# 12.3
# enter 19.22 mpg Imp.
# enter 19.22 mpg Imp. 19.22
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 12.7
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 11.8
# 11.4
# 23.7
# 13.4
# 12.8
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# 21.5
# 19.5
# 9.3
# 15.9
# 8.7
# 16.8
# 17.2
# 7.7
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 10.1
# 13.1
# 16.0
# 9.8
# 9.8
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 10.7
# 12.9
# 10.6
# 15.6
# 16.0
# 9.0
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 11.4
# 16.8
# 15.4
# 13.6
# 12.5
# 14.7
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 12.1
# 9.7
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 8.4
# 11.1
# 5.4
# 17.5
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 12.3
# 11.7
# enter 16.14 mpg Imp.
# enter 16.14 mpg Imp. 16.14
# 16.6
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 7.5
# 11.8
# 8.1
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# enter 15.27 mpg Imp.
# enter 15.27 mpg Imp. 15.27
# 16.6
# 12.9
# 11.9
# 12.0
# 9.5
# 16.0
# 10.9
# 9.2
# 12.4
# 4.2
# 8.0
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# 11.5
# 15.8
# enter 16.92 mpg Imp.
# enter 16.92 mpg Imp. 16.92
# 13.1
# 11.1
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 19.8
# 12.6
# 14.9
# 9.6
# 9.8
# 9.7
# enter 17.77 mpg Imp.
# enter 17.77 mpg Imp. 17.77
# 10.3
# 13.3
# 14.3
# 16.7
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# 4.2
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 9.0
# 15.9
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 9.9
# 13.1
# 9.1
# 9.0
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 21.3
# 9.3
# 27.3
# 11.7
# 13.3
# 15.4
# 12.1
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 11.4
# 17.7
# 11.5
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# enter 22.78 mpg Imp.
# enter 22.78 mpg Imp. 22.78
# enter 21.40 mpg Imp.
# enter 21.40 mpg Imp. 21.4
# 19.8
# 9.8
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# 16.2
# 15.5
# 12.8
# 12.7
# 16.6
# 10.4
# 17.4
# 9.0
# 15.7
# 8.2
# 16.0
# 15.8
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 10.2
# 10.4
# 9.5
# enter 18.58 mpg Imp.
# enter 18.58 mpg Imp. 18.58
# 8.9
# 7.9
# 8.5
# 30.0
# 9.9
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 19.1
# 11.1
# 12.0
# 8.6
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# enter 16.52 mpg Imp.
# enter 16.52 mpg Imp. 16.52
# enter 13.92 mpg Imp.
# enter 13.92 mpg Imp. 13.92
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 9.1
# 12.1
# 17.7
# enter 16.62 mpg Imp.
# enter 16.62 mpg Imp. 16.62
# 9.3
# 13.7
# 14.0
# 4.4
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 14.2
# enter 13.52 mpg Imp.
# enter 13.52 mpg Imp. 13.52
# 11.2
# 11.6
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 11.9
# 10.9
# enter 21.73 mpg Imp.
# enter 21.73 mpg Imp. 21.73
# 13.2
# 20.6
# 8.1
# 15.8
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 16.0
# enter 13.32 mpg Imp.
# enter 13.32 mpg Imp. 13.32
# 10.8
# 14.3
# 10.2
# 15.4
# 10.7
# 9.5
# 21.0
# enter 16.92 mpg Imp.
# enter 16.92 mpg Imp. 16.92
# 11.6
# 15.3
# 9.8
# 11.1
# enter 15.03 mpg Imp.
# enter 15.03 mpg Imp. 15.03
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# 10.3
# 12.7
# 9.8
# 8.3
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# 9.7
# 14.6
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 19.0
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# enter 16.14 mpg Imp.
# enter 16.14 mpg Imp. 16.14
# 9.7
# 17.2
# 12.3
# 9.8
# 16.0
# enter 34.45 mpg Imp.
# enter 34.45 mpg Imp. 34.45
# 20.1
# 8.7
# 16.7
# 10.5
# 10.7
# 10.7
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# enter 17.66 mpg Imp.
# enter 17.66 mpg Imp. 17.66
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 10.8
# 9.5
# 16.1
# 10.8
# 12.7
# 14.4
# enter 14.05 mpg Imp.
# enter 14.05 mpg Imp. 14.05
# enter 14.56 mpg Imp.
# enter 14.56 mpg Imp. 14.56
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 11.6
# 15.6
# 14.3
# 13.1
# 21.5
# 16.2
# enter 33.63 mpg Imp.
# enter 33.63 mpg Imp. 33.63
# 9.6
# 13.3
# 16.1
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 9.5
# enter 17.02 mpg Imp.
# enter 17.02 mpg Imp. 17.02
# 18.6
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 18.7
# 8.4
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 14.9
# 8.7
# 18.0
# enter 13.26 mpg Imp.
# enter 13.26 mpg Imp. 13.26
# enter 34.45 mpg Imp.
# enter 34.45 mpg Imp. 34.45
# 12.7
# 9.5
# 9.6
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 16.9
# 22.6
# 8.5
# enter 19.48 mpg Imp.
# enter 19.48 mpg Imp. 19.48
# enter 65.69 mpg Imp.
# enter 65.69 mpg Imp. 65.69
# 22.1
# 8.6
# 13.6
# 18.6
# 7.3
# 9.5
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# 13.3
# 5.6
# 15.2
# 11.2
# 14.6
# 9.8
# 15.9
# 10.6
# 9.8
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 18.4
# 7.3
# 16.0
# 16.8
# 9.5
# 10.8
# 16.6
# 14.0
# 10.8
# 21.0
# 24.4
# 16.6
# enter 15.61 mpg Imp.
# enter 15.61 mpg Imp. 15.61
# 16.9
# 11.5
# 10.4
# 10.1
# 9.3
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# 22.6
# 12.5
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# 10.3
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# 10.2
# 15.8
# 15.8
# 20.8
# 11.4
# 12.2
# 10.8
# 8.1
# 30.0
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 17.5
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# 12.5
# 9.7
# 10.5
# 12.9
# 8.0
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 13.0
# 18.4
# 7.5
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# enter 17.44 mpg Imp.
# enter 17.44 mpg Imp. 17.44
# 13.0
# 9.7
# 9.1
# 13.0
# 8.1
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 15.9
# 19.1
# enter 18.71 mpg Imp.
# enter 18.71 mpg Imp. 18.71
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# 15.6
# 10.1
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# 19.1
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 9.4
# 7.6
# 10.4
# 29.4
# 15.5
# 12.0
# enter 17.44 mpg Imp.
# enter 17.44 mpg Imp. 17.44
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 18.5
# 9.2
# enter 20.18 mpg Imp.
# enter 20.18 mpg Imp. 20.18
# 17.2
# 4.3
# 13.9
# 15.4
# 10.6
# 9.8
# 7.4
# 14.0
# 20.8
# 27.1
# 10.4
# enter 20.03 mpg Imp.
# enter 20.03 mpg Imp. 20.03
# 11.7
# 10.4
# 14.9
# enter 22.07 mpg Imp.
# enter 22.07 mpg Imp. 22.07
# 12.0
# 16.8
# 15.1
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 9.5
# 14.9
# 20.1
# 11.8
# 9.3
# 9.6
# 10.5
# 17.7
# 13.7
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 16.3
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 13.6
# enter 17.66 mpg Imp.
# enter 17.66 mpg Imp. 17.66
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 11.8
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 12.4
# 12.8
# 12.4
# enter 21.73 mpg Imp.
# enter 21.73 mpg Imp. 21.73
# 4.2
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 16.4
# 11.5
# 10.6
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 17.0
# 15.0
# 10.0
# 11.1
# 10.7
# enter 18.71 mpg Imp.
# enter 18.71 mpg Imp. 18.71
# 8.9
# 17.0
# 11.5
# 12.3
# enter 61.41 mpg Imp.
# enter 61.41 mpg Imp. 61.41
# 17.4
# 9.5
# 19.1
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 12.6
# 9.9
# enter 13.92 mpg Imp.
# enter 13.92 mpg Imp. 13.92
# 11.1
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 17.3
# 13.8
# 13.7
# 17.2
# 8.4
# 9.5
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 17.44 mpg Imp.
# enter 17.44 mpg Imp. 17.44
# 11.3
# 11.7
# 4.2
# 10.8
# 10.3
# 13.8
# enter 34.45 mpg Imp.
# enter 34.45 mpg Imp. 34.45
# 13.5
# 10.6
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 13.9
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# enter 37.17 mpg Imp.
# enter 37.17 mpg Imp. 37.17
# 7.4
# 8.9
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 15.9
# 10.1
# 23.5
# 14.5
# 10.0
# 16.4
# 15.0
# 15.9
# enter 32.47 mpg Imp.
# enter 32.47 mpg Imp. 32.47
# 11.3
# 9.2
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 22.8
# 16.5
# 16.2
# 9.9
# 15.3
# 17.2
# 4.2
# enter 57.65 mpg Imp.
# enter 57.65 mpg Imp. 57.65
# 12.7
# 11.4
# 10.6
# 7.2
# 12.2
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 10.6
# 10.2
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 11.8
# 9.1
# 11.2
# 12.9
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# 8.5
# 17.9
# 10.4
# 8.1
# 11.2
# 16.8
# 11.5
# 17.2
# 9.1
# 10.0
# 10.7
# 8.1
# 5.4
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 18.2
# 8.6
# 10.9
# enter 13.26 mpg Imp.
# enter 13.26 mpg Imp. 13.26
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 20.4
# 16.3
# 10.9
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 12.7
# 14.0
# 10.6
# 14.1
# 12.0
# 8.6
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 9.7
# 10.5
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# 13.3
# 9.6
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 12.0
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# enter 36.69 mpg Imp.
# enter 36.69 mpg Imp. 36.69
# 20.4
# 9.6
# 10.2
# 17.1
# 10.8
# 10.6
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 11.5
# 8.4
# 11.8
# enter 14.71 mpg Imp.
# enter 14.71 mpg Imp. 14.71
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# 17.2
# enter 13.20 mpg Imp.
# enter 13.20 mpg Imp. 13.2
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 15.9
# 19.8
# 17.5
# 10.9
# 14.7
# 10.8
# 4.3
# 21.8
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# enter 15.78 mpg Imp.
# enter 15.78 mpg Imp. 15.78
# 9.2
# 11.8
# 10.3
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 13.2
# 4.2
# 16.0
# 10.8
# 10.0
# 14.6
# 6.6
# 11.7
# 11.0
# 11.6
# 12.6
# enter 19.09 mpg Imp.
# enter 19.09 mpg Imp. 19.09
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 18.3
# 14.8
# 18.0
# 11.2
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 9.9
# 10.5
# enter 17.55 mpg Imp.
# enter 17.55 mpg Imp. 17.55
# 16.4
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 12.4
# 16.0
# 19.4
# 9.8
# 8.8
# 16.2
# enter 22.60 mpg Imp.
# enter 22.60 mpg Imp. 22.6
# 10.3
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 11.7
# 10.5
# 11.1
# 10.4
# 13.8
# 7.1
# 4.3
# 8.1
# 9.3
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 12.8
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# 9.2
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 18.0
# 10.7
# 15.2
# 8.6
# 16.7
# 7.9
# 15.9
# 15.0
# 11.6
# 15.9
# 12.6
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 11.8
# 10.3
# 19.7
# 17.5
# 12.6
# 23.1
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 11.1
# 14.5
# enter 33.23 mpg Imp.
# enter 33.23 mpg Imp. 33.23
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# 14.6
# 9.5
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 12.6
# 9.3
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# 11.6
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 11.0
# 12.8
# 11.3
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 18.2
# 12.5
# 10.7
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 13.4
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 8.1
# enter 57.65 mpg Imp.
# enter 57.65 mpg Imp. 57.65
# 10.0
# 9.2
# enter 33.23 mpg Imp.
# enter 33.23 mpg Imp. 33.23
# 11.6
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 9.6
# 10.4
# 8.8
# 11.2
# 19.4
# enter 13.98 mpg Imp.
# enter 13.98 mpg Imp. 13.98
# 21.0
# 13.5
# 9.5
# 18.0
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 11.7
# 10.2
# 8.5
# 12.6
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 13.6
# 13.5
# 10.0
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 8.8
# 21.3
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 18.8
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 17.2
# 9.4
# 10.7
# 11.4
# enter 48.70 mpg Imp.
# enter 48.70 mpg Imp. 48.7
# 5.1
# 8.6
# 8.8
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# enter 38.70 mpg Imp.
# enter 38.70 mpg Imp. 38.7
# 5.4
# 9.3
# 12.5
# 13.6
# 14.9
# 5.8
# 12.5
# 4.2
# 25.2
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 19.2
# enter 35.76 mpg Imp.
# enter 35.76 mpg Imp. 35.76
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# 15.1
# 8.0
# 10.9
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# 10.3
# 14.7
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 8.4
# 12.5
# 9.9
# enter 12.28 mpg Imp.
# enter 12.28 mpg Imp. 12.28
# 12.4
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 9.5
# 8.9
# enter 20.32 mpg Imp.
# enter 20.32 mpg Imp. 20.32
# 18.9
# 19.6
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 9.2
# enter 22.60 mpg Imp.
# enter 22.60 mpg Imp. 22.6
# 16.2
# 18.4
# 12.3
# 14.9
# 15.4
# 13.5
# 10.0
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 10.8
# enter 40.94 mpg Imp.
# enter 40.94 mpg Imp. 40.94
# 23.9
# enter 22.07 mpg Imp.
# enter 22.07 mpg Imp. 22.07
# 10.8
# 17.3
# 21.4
# 10.6
# 5.8
# 11.5
# 13.6
# 9.2
# 12.6
# 9.2
# 15.9
# 10.5
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# 9.4
# 8.8
# 10.8
# 16.3
# 4.8
# 20.9
# 10.2
# enter 37.66 mpg Imp.
# enter 37.66 mpg Imp. 37.66
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 11.8
# 11.7
# 9.8
# 14.9
# 24.0
# 9.9
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 10.7
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 12.3
# enter 13.52 mpg Imp.
# enter 13.52 mpg Imp. 13.52
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 4.6
# 8.5
# 18.2
# 16.2
# 17.2
# 11.4
# 11.1
# 14.9
# 8.9
# 9.1
# 9.0
# 10.1
# 11.2
# 10.2
# enter 13.08 mpg Imp.
# enter 13.08 mpg Imp. 13.08
# 9.2
# 18.0
# enter 13.20 mpg Imp.
# enter 13.20 mpg Imp. 13.2
# 20.5
# enter 52.31 mpg Imp.
# enter 52.31 mpg Imp. 52.31
# enter 14.95 mpg Imp.
# enter 14.95 mpg Imp. 14.95
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 15.3
# 4.2
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# 17.2
# enter 21.56 mpg Imp.
# enter 21.56 mpg Imp. 21.56
# 11.7
# 18.1
# 4.3
# 10.3
# 12.5
# 9.7
# 15.6
# 10.3
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 18.5
# 18.4
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 10.6
# 8.4
# 13.8
# 6.8
# 18.1
# 10.6
# 10.2
# 12.5
# 11.0
# 15.3
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 8.9
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 13.1
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 12.8
# 15.1
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 11.1
# 4.2
# 9.8
# 9.0
# 13.3
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 19.5
# 13.3
# 17.5
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 15.3
# 13.2
# 15.9
# 12.7
# 5.5
# 15.0
# 15.4
# 14.1
# 11.0
# 10.2
# 10.3
# 21.5
# 8.8
# 29.6
# 11.2
# 12.1
# 9.8
# 14.4
# 9.0
# enter 19.35 mpg Imp.
# enter 19.35 mpg Imp. 19.35
# 10.5
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# 12.6
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# 4.2
# enter 14.64 mpg Imp.
# enter 14.64 mpg Imp. 14.64
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# enter 12.18 mpg Imp.
# enter 12.18 mpg Imp. 12.18
# 8.6
# 26.7
# 12.8
# enter 58.85 mpg Imp.
# enter 58.85 mpg Imp. 58.85
# 4.3
# 8.8
# 8.7
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# enter 20.62 mpg Imp.
# enter 20.62 mpg Imp. 20.62
# 12.0
# enter 13.85 mpg Imp.
# enter 13.85 mpg Imp. 13.85
# 9.1
# 12.0
# 15.8
# 13.2
# 11.5
# 25.1
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 10.3
# 22.8
# enter 16.05 mpg Imp.
# enter 16.05 mpg Imp. 16.05
# 11.6
# 9.4
# enter 11.72 mpg Imp.
# enter 11.72 mpg Imp. 11.72
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 5.2
# 13.7
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 13.0
# 15.9
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 13.0
# 9.7
# 7.9
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 10.1
# 11.6
# 19.1
# 7.4
# 14.0
# 9.0
# enter 35.31 mpg Imp.
# enter 35.31 mpg Imp. 35.31
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 14.3
# 10.1
# enter 16.52 mpg Imp.
# enter 16.52 mpg Imp. 16.52
# 8.9
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 18.0
# 4.2
# 14.0
# enter 21.56 mpg Imp.
# enter 21.56 mpg Imp. 21.56
# 11.1
# 4.2
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# 8.3
# 17.0
# 8.2
# 12.6
# 8.1
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# enter 14.49 mpg Imp.
# enter 14.49 mpg Imp. 14.49
# 10.0
# 5.0
# 15.7
# 8.4
# 10.4
# 19.8
# 11.5
# 11.3
# enter 36.22 mpg Imp.
# enter 36.22 mpg Imp. 36.22
# 8.9
# 9.9
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 16.5
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# 8.7
# 14.9
# 8.2
# 14.0
# 10.1
# 16.4
# 11.6
# 11.7
# 11.6
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 8.9
# 21.2
# 12.4
# 10.1
# 12.8
# 16.1
# 19.3
# 11.4
# 11.3
# 10.8
# 10.2
# 7.9
# 8.3
# 14.6
# 7.5
# 18.2
# 13.8
# 12.9
# 4.2
# 17.5
# 11.6
# 11.4
# 9.6
# 10.7
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 14.4
# 13.8
# 13.4
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# enter 15.03 mpg Imp.
# enter 15.03 mpg Imp. 15.03
# enter 14.71 mpg Imp.
# enter 14.71 mpg Imp. 14.71
# 15.7
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 8.5
# 10.6
# 18.9
# enter 20.47 mpg Imp.
# enter 20.47 mpg Imp. 20.47
# 11.4
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 11.6
# enter 12.61 mpg Imp.
# enter 12.61 mpg Imp. 12.61
# 23.2
# 13.2
# 9.3
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 19.9
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# enter 14.20 mpg Imp.
# enter 14.20 mpg Imp. 14.2
# 11.8
# 17.3
# 12.3
# 9.1
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 17.8
# enter 17.66 mpg Imp.
# enter 17.66 mpg Imp. 17.66
# 4.2
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 11.4
# 19.3
# 11.9
# 12.2
# 15.1
# 10.9
# 13.5
# enter 34.87 mpg Imp.
# enter 34.87 mpg Imp. 34.87
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# 20.4
# enter 13.14 mpg Imp.
# enter 13.14 mpg Imp. 13.14
# 11.9
# 7.9
# 11.6
# enter 19.89 mpg Imp.
# enter 19.89 mpg Imp. 19.89
# 8.8
# 11.5
# 12.6
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 10.4
# 13.5
# 14.6
# 16.2
# 12.7
# 20.0
# 16.6
# 12.8
# 9.8
# 9.7
# 12.2
# 12.4
# 11.3
# 16.2
# 15.2
# 12.2
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# 12.1
# 11.2
# 9.7
# 4.8
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 12.6
# 9.3
# 10.2
# 12.5
# 10.0
# 12.2
# enter 17.77 mpg Imp.
# enter 17.77 mpg Imp. 17.77
# 12.7
# 10.9
# 8.5
# 9.7
# 21.8
# 14.8
# 13.4
# 11.4
# 9.3
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 18.7
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 15.7
# 12.0
# 9.9
# 4.9
# 10.9
# 9.8
# 19.1
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 20.3
# 7.7
# 16.8
# 15.7
# 12.9
# 10.8
# 16.8
# 11.4
# 21.6
# 9.6
# 9.2
# 8.9
# 10.1
# 11.2
# enter 17.02 mpg Imp.
# enter 17.02 mpg Imp. 17.02
# enter 14.20 mpg Imp.
# enter 14.20 mpg Imp. 14.2
# 17.6
# 13.3
# 11.8
# 9.3
# 14.7
# enter 39.79 mpg Imp.
# enter 39.79 mpg Imp. 39.79
# 12.2
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 10.4
# 16.0
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 10.1
# 20.4
# 17.7
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# 16.9
# 13.0
# 10.9
# 17.9
# 11.8
# 13.3
# 6.3
# 10.9
# 9.1
# 10.1
# 10.9
# 9.6
# 7.1
# 22.9
# enter 13.92 mpg Imp.
# enter 13.92 mpg Imp. 13.92
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 11.5
# 11.9
# 10.4
# 12.0
# enter 20.03 mpg Imp.
# enter 20.03 mpg Imp. 20.03
# 8.7
# 15.1
# 15.7
# 10.4
# 10.7
# enter 18.58 mpg Imp.
# enter 18.58 mpg Imp. 18.58
# 10.1
# enter 43.46 mpg Imp.
# enter 43.46 mpg Imp. 43.46
# 11.7
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 12.7
# 9.4
# 8.4
# 10.6
# 14.9
# enter 16.14 mpg Imp.
# enter 16.14 mpg Imp. 16.14
# 8.0
# 24.3
# 7.9
# 11.2
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# 9.7
# 7.7
# 22.5
# 12.1
# enter 20.18 mpg Imp.
# enter 20.18 mpg Imp. 20.18
# 12.0
# 10.2
# 14.8
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# 19.3
# 12.6
# 8.1
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 14.6
# 10.7
# 15.5
# 19.8
# 12.9
# 17.2
# 17.4
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# 21.0
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# 10.1
# enter 13.98 mpg Imp.
# enter 13.98 mpg Imp. 13.98
# 11.6
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 5.9
# 8.8
# 13.0
# 12.4
# 11.2
# enter 13.65 mpg Imp.
# enter 13.65 mpg Imp. 13.65
# 9.0
# 9.6
# 10.4
# 8.6
# 13.3
# enter 17.77 mpg Imp.
# enter 17.77 mpg Imp. 17.77
# 11.5
# 15.5
# enter 13.92 mpg Imp.
# enter 13.92 mpg Imp. 13.92
# 12.9
# enter 16.05 mpg Imp.
# enter 16.05 mpg Imp. 16.05
# 25.3
# 19.9
# 10.8
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 8.4
# enter 19.35 mpg Imp.
# enter 19.35 mpg Imp. 19.35
# 14.9
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# 8.4
# 14.0
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# 20.0
# 17.8
# 15.1
# 7.6
# 16.3
# 11.4
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 8.3
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 13.7
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 16.9
# 4.2
# 17.5
# 10.0
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 18.2
# 13.8
# 16.6
# 15.4
# 14.5
# 7.3
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 11.7
# 9.0
# 15.9
# 15.9
# 11.5
# 11.5
# enter 33.23 mpg Imp.
# enter 33.23 mpg Imp. 33.23
# 4.2
# 11.8
# 12.5
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# enter 21.08 mpg Imp.
# enter 21.08 mpg Imp. 21.08
# enter 12.78 mpg Imp.
# enter 12.78 mpg Imp. 12.78
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# enter 33.63 mpg Imp.
# enter 33.63 mpg Imp. 33.63
# 9.7
# 10.5
# 14.8
# 14.0
# 11.4
# 13.1
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 12.4
# 13.4
# 16.9
# 8.1
# 16.4
# 15.2
# 9.3
# 14.0
# 17.4
# enter 18.96 mpg Imp.
# enter 18.96 mpg Imp. 18.96
# 10.2
# enter 22.60 mpg Imp.
# enter 22.60 mpg Imp. 22.6
# enter 21.08 mpg Imp.
# enter 21.08 mpg Imp. 21.08
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 9.1
# 11.2
# 11.8
# 13.4
# 14.2
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# 11.6
# 20.2
# 10.6
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 11.1
# 12.8
# 12.3
# 17.4
# 10.8
# 12.5
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 19.4
# 10.9
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# enter 14.34 mpg Imp.
# enter 14.34 mpg Imp. 14.34
# 9.0
# enter 40.35 mpg Imp.
# enter 40.35 mpg Imp. 40.35
# 11.5
# 9.8
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# enter 22.78 mpg Imp.
# enter 22.78 mpg Imp. 22.78
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 9.4
# 16.6
# 15.3
# 16.7
# 7.5
# 14.8
# 4.3
# 11.6
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# enter 28.25 mpg Imp.
# enter 28.25 mpg Imp. 28.25
# 11.8
# 10.4
# 11.6
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 12.9
# 12.6
# 14.9
# 18.8
# enter 37.66 mpg Imp.
# enter 37.66 mpg Imp. 37.66
# enter 16.52 mpg Imp.
# enter 16.52 mpg Imp. 16.52
# 8.6
# 21.5
# 12.1
# 20.0
# 10.4
# 19.9
# 12.0
# 11.6
# 11.6
# 11.3
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 13.4
# 12.4
# 22.1
# enter 15.27 mpg Imp.
# enter 15.27 mpg Imp. 15.27
# 8.7
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 10.4
# 10.0
# 19.1
# enter 22.07 mpg Imp.
# enter 22.07 mpg Imp. 22.07
# 16.2
# 9.1
# enter 12.96 mpg Imp.
# enter 12.96 mpg Imp. 12.96
# 9.9
# 9.8
# 9.7
# 11.7
# 13.9
# 14.9
# enter 20.47 mpg Imp.
# enter 20.47 mpg Imp. 20.47
# 14.5
# 10.4
# 7.5
# 11.0
# 10.7
# enter 13.02 mpg Imp.
# enter 13.02 mpg Imp. 13.02
# 11.9
# 12.4
# 11.2
# 11.2
# 19.0
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 15.7
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 14.8
# enter 36.69 mpg Imp.
# enter 36.69 mpg Imp. 36.69
# 10.2
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 11.1
# 9.8
# 9.4
# 14.6
# 15.9
# 12.6
# 14.5
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 8.5
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 9.9
# 17.5
# 14.4
# 17.5
# 10.4
# 11.1
# 17.2
# 10.9
# 10.1
# 4.8
# 12.5
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# 11.2
# 13.7
# 10.3
# 11.7
# enter 19.22 mpg Imp.
# enter 19.22 mpg Imp. 19.22
# enter 46.31 mpg Imp.
# enter 46.31 mpg Imp. 46.31
# 8.6
# 13.2
# 5.3
# 11.3
# 12.9
# 13.0
# 9.3
# 10.0
# 7.3
# 7.1
# 9.7
# enter 17.22 mpg Imp.
# enter 17.22 mpg Imp. 17.22
# 8.8
# 8.7
# 13.3
# 13.0
# 10.2
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# 20.2
# 12.1
# 9.3
# 13.3
# 16.0
# enter 15.96 mpg Imp.
# enter 15.96 mpg Imp. 15.96
# enter 15.78 mpg Imp.
# enter 15.78 mpg Imp. 15.78
# 24.4
# 18.8
# 11.7
# 9.9
# 18.7
# 11.8
# 13.4
# 10.4
# 17.9
# 15.6
# 4.4
# 4.7
# 11.2
# 17.8
# 4.2
# enter 15.61 mpg Imp.
# enter 15.61 mpg Imp. 15.61
# 5.3
# 15.8
# 15.1
# 10.5
# 10.4
# 8.5
# 12.5
# 16.5
# 9.8
# enter 17.33 mpg Imp.
# enter 17.33 mpg Imp. 17.33
# 9.1
# 11.9
# 11.2
# 10.2
# 17.0
# 11.2
# 8.8
# 11.0
# 14.8
# 13.2
# 10.3
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# 11.7
# 16.1
# 9.1
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 12.2
# 13.0
# 9.4
# 17.4
# 21.3
# 8.7
# 11.5
# 16.6
# enter 17.55 mpg Imp.
# enter 17.55 mpg Imp. 17.55
# 11.2
# 11.7
# 12.6
# 10.9
# 11.5
# 14.9
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# enter 14.12 mpg Imp.
# enter 14.12 mpg Imp. 14.12
# 12.0
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 22.0
# 8.8
# 11.1
# 17.2
# enter 17.55 mpg Imp.
# enter 17.55 mpg Imp. 17.55
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 12.9
# 9.9
# 17.4
# 18.6
# 10.1
# 17.5
# 19.1
# 14.0
# 15.8
# 9.9
# 8.7
# 14.3
# enter 37.17 mpg Imp.
# enter 37.17 mpg Imp. 37.17
# 10.6
# 10.6
# enter 65.69 mpg Imp.
# enter 65.69 mpg Imp. 65.69
# enter 16.14 mpg Imp.
# enter 16.14 mpg Imp. 16.14
# 13.7
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# 9.2
# 18.2
# 11.6
# 14.0
# 17.6
# 16.0
# 7.9
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# 15.7
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 16.3
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 55.39 mpg Imp.
# enter 55.39 mpg Imp. 55.39
# 11.6
# 7.9
# 9.0
# enter 41.54 mpg Imp.
# enter 41.54 mpg Imp. 41.54
# 9.9
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 16.4
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 8.5
# 13.4
# 13.3
# 19.6
# 15.2
# 16.5
# 9.6
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 11.1
# 10.9
# 7.7
# 15.0
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# 16.3
# 9.1
# 15.8
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# enter 15.03 mpg Imp.
# enter 15.03 mpg Imp. 15.03
# 16.7
# 8.8
# 7.6
# 21.7
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# 8.8
# 11.3
# 12.8
# 25.8
# enter 18.22 mpg Imp.
# enter 18.22 mpg Imp. 18.22
# 18.3
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 9.5
# 15.8
# 11.3
# 21.1
# enter 15.11 mpg Imp.
# enter 15.11 mpg Imp. 15.11
# 10.4
# 12.4
# 10.6
# 16.2
# 7.9
# 12.8
# enter 16.14 mpg Imp.
# enter 16.14 mpg Imp. 16.14
# 10.3
# 18.6
# 29.6
# 10.8
# enter 20.62 mpg Imp.
# enter 20.62 mpg Imp. 20.62
# 9.8
# 9.7
# 8.6
# 12.3
# 12.0
# 9.1
# 9.1
# 15.8
# enter 34.87 mpg Imp.
# enter 34.87 mpg Imp. 34.87
# 10.7
# 21.0
# 10.2
# 9.7
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# 10.4
# 9.4
# enter 13.08 mpg Imp.
# enter 13.08 mpg Imp. 13.08
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 11.6
# 18.0
# 17.6
# 4.2
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 14.7
# 18.8
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 16.8
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 20.5
# 6.6
# 10.1
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 12.0
# 8.8
# 16.8
# 5.0
# 11.5
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 9.4
# 9.0
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# enter 57.65 mpg Imp.
# enter 57.65 mpg Imp. 57.65
# enter 18.96 mpg Imp.
# enter 18.96 mpg Imp. 18.96
# enter 17.77 mpg Imp.
# enter 17.77 mpg Imp. 17.77
# 6.9
# 17.6
# 10.5
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 14.0
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 10.2
# 11.0
# 16.2
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 9.2
# 12.0
# 17.0
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# enter 36.22 mpg Imp.
# enter 36.22 mpg Imp. 36.22
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 13.7
# 22.0
# 8.7
# 13.1
# 10.7
# enter 18.96 mpg Imp.
# enter 18.96 mpg Imp. 18.96
# 14.9
# 15.0
# 10.4
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# enter 58.85 mpg Imp.
# enter 58.85 mpg Imp. 58.85
# enter 34.87 mpg Imp.
# enter 34.87 mpg Imp. 34.87
# 11.8
# 20.1
# 13.9
# 13.8
# 10.0
# 14.3
# 18.8
# 12.5
# 18.0
# 14.0
# 12.0
# 19.9
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 10.9
# 10.5
# 9.0
# 8.5
# 4.8
# 14.7
# 12.5
# enter 17.33 mpg Imp.
# enter 17.33 mpg Imp. 17.33
# 16.3
# 9.6
# 18.1
# 18.5
# 9.5
# 12.1
# 11.0
# 8.9
# 21.0
# 12.9
# 8.2
# 13.9
# 9.8
# 8.5
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# 12.5
# 17.9
# 18.4
# 14.6
# 9.3
# 12.3
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 9.3
# 8.4
# 12.8
# 20.8
# 18.1
# 8.7
# 11.8
# 12.4
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 13.8
# 16.6
# 8.6
# 14.1
# 19.9
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 17.1
# 10.2
# 8.2
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 16.1
# 11.5
# enter 20.92 mpg Imp.
# enter 20.92 mpg Imp. 20.92
# 16.3
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# 9.1
# 13.3
# 21.7
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 11.6
# 13.1
# 10.4
# enter 22.42 mpg Imp.
# enter 22.42 mpg Imp. 22.42
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 11.0
# 12.5
# 15.1
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# 14.0
# enter 34.87 mpg Imp.
# enter 34.87 mpg Imp. 34.87
# enter 22.78 mpg Imp.
# enter 22.78 mpg Imp. 22.78
# 10.9
# 10.5
# 11.7
# enter 12.96 mpg Imp.
# enter 12.96 mpg Imp. 12.96
# 11.3
# 8.6
# 10.8
# enter 16.33 mpg Imp.
# enter 16.33 mpg Imp. 16.33
# 10.9
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 14.0
# 14.9
# 17.5
# 19.5
# 8.3
# 22.2
# 11.0
# 10.0
# 16.4
# 14.5
# 15.8
# 16.2
# 14.9
# 11.3
# 5.2
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# 9.3
# 10.6
# 12.4
# 11.7
# 11.4
# 16.5
# 15.0
# 11.3
# 19.7
# 11.0
# 10.9
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 7.6
# 19.2
# 13.5
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# enter 16.92 mpg Imp.
# enter 16.92 mpg Imp. 16.92
# 12.8
# 8.6
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 12.3
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 16.8
# enter 13.71 mpg Imp.
# enter 13.71 mpg Imp. 13.71
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# enter 15.96 mpg Imp.
# enter 15.96 mpg Imp. 15.96
# 10.4
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 16.7
# 11.5
# 8.3
# 16.2
# 11.3
# 11.1
# 15.9
# enter 17.55 mpg Imp.
# enter 17.55 mpg Imp. 17.55
# 11.2
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 15.1
# 6.8
# 4.8
# 23.2
# 11.3
# 12.0
# 14.4
# 17.2
# 8.1
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# 17.5
# 9.1
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# 10.6
# 17.9
# enter 21.56 mpg Imp.
# enter 21.56 mpg Imp. 21.56
# 11.6
# 21.3
# 12.3
# 10.6
# 14.6
# 16.5
# 5.3
# 14.6
# 9.2
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 7.0
# enter 48.70 mpg Imp.
# enter 48.70 mpg Imp. 48.7
# 8.7
# 9.8
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 14.6
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# 6.9
# enter 11.39 mpg Imp.
# enter 11.39 mpg Imp. 11.39
# 13.3
# 12.6
# 14.5
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 11.3
# 16.2
# 14.3
# 10.7
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 12.9
# 17.7
# 18.7
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 9.5
# 16.5
# 10.7
# 10.0
# 11.7
# enter 41.54 mpg Imp.
# enter 41.54 mpg Imp. 41.54
# 10.8
# 13.2
# 19.2
# enter 20.47 mpg Imp.
# enter 20.47 mpg Imp. 20.47
# 15.2
# 12.4
# 9.4
# 11.6
# enter 57.65 mpg Imp.
# enter 57.65 mpg Imp. 57.65
# 11.0
# 15.2
# 8.2
# 16.3
# 15.7
# 4.2
# 12.6
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 13.3
# 18.8
# 13.4
# 10.1
# 13.2
# 8.5
# 13.4
# 15.5
# 15.9
# 14.6
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# 12.8
# 8.2
# 9.7
# 17.1
# 11.2
# 17.6
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# enter 15.78 mpg Imp.
# enter 15.78 mpg Imp. 15.78
# 10.5
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 16.1
# 9.2
# 10.9
# 14.9
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# 11.9
# 5.9
# 11.0
# 18.7
# 11.1
# 11.5
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 17.5
# 10.1
# 5.3
# enter 21.90 mpg Imp.
# enter 21.90 mpg Imp. 21.9
# 14.9
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# enter 16.05 mpg Imp.
# enter 16.05 mpg Imp. 16.05
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# enter 14.95 mpg Imp.
# enter 14.95 mpg Imp. 14.95
# 9.2
# enter 20.77 mpg Imp.
# enter 20.77 mpg Imp. 20.77
# 10.5
# 17.3
# 16.8
# 5.0
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 14.1
# enter 19.89 mpg Imp.
# enter 19.89 mpg Imp. 19.89
# 13.3
# enter 20.18 mpg Imp.
# enter 20.18 mpg Imp. 20.18
# 13.6
# 11.8
# 16.3
# 10.4
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 9.7
# 16.4
# 9.2
# 10.9
# 10.0
# 16.6
# 5.8
# 7.9
# 15.5
# enter 47.88 mpg Imp.
# enter 47.88 mpg Imp. 47.88
# enter 15.35 mpg Imp.
# enter 15.35 mpg Imp. 15.35
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 14.3
# 10.8
# 7.9
# 13.9
# 9.1
# 15.3
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# 12.9
# 8.5
# 17.1
# 15.6
# 18.7
# 16.9
# 11.3
# 9.7
# 15.4
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 4.2
# 10.9
# 8.8
# 8.2
# 4.4
# 11.3
# 10.3
# 11.7
# 11.4
# enter 18.58 mpg Imp.
# enter 18.58 mpg Imp. 18.58
# 17.9
# 8.5
# 9.2
# 13.6
# 10.7
# 11.2
# 9.0
# 7.2
# 9.6
# 7.9
# 18.0
# enter 17.55 mpg Imp.
# enter 17.55 mpg Imp. 17.55
# 10.7
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 9.0
# 11.1
# 11.3
# 13.0
# 11.7
# 12.3
# 10.6
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 8.8
# 22.4
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 7.9
# 12.8
# enter 21.24 mpg Imp.
# enter 21.24 mpg Imp. 21.24
# 10.6
# 17.7
# 17.1
# 14.5
# enter 20.32 mpg Imp.
# enter 20.32 mpg Imp. 20.32
# enter 18.71 mpg Imp.
# enter 18.71 mpg Imp. 18.71
# 16.9
# 11.2
# 10.9
# 15.6
# 16.2
# 8.6
# 9.0
# 11.8
# enter 19.22 mpg Imp.
# enter 19.22 mpg Imp. 19.22
# 15.4
# enter 27.43 mpg Imp.
# enter 27.43 mpg Imp. 27.43
# 11.6
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 17.9
# 12.7
# 10.0
# 10.6
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# 21.7
# 11.4
# 13.2
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# 10.0
# 12.5
# 10.0
# 15.0
# 11.8
# 13.3
# 18.9
# 11.7
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 21.8
# 11.6
# 12.5
# 8.4
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# 8.7
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# 12.6
# 11.7
# 17.5
# 4.6
# 15.9
# 10.0
# 8.8
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 10.5
# 11.2
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# 15.7
# enter 54.32 mpg Imp.
# enter 54.32 mpg Imp. 54.32
# 10.0
# 10.1
# 18.2
# 12.0
# enter 17.33 mpg Imp.
# enter 17.33 mpg Imp. 17.33
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# 11.2
# 10.0
# 4.2
# 6.1
# 10.9
# 10.9
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 14.4
# 10.1
# enter 65.69 mpg Imp.
# enter 65.69 mpg Imp. 65.69
# 12.4
# 8.6
# 9.1
# 9.2
# 13.9
# 19.1
# 23.5
# enter 31.04 mpg Imp.
# enter 31.04 mpg Imp. 31.04
# 12.2
# 14.5
# 16.7
# 12.3
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# enter 14.41 mpg Imp.
# enter 14.41 mpg Imp. 14.41
# enter 44.84 mpg Imp.
# enter 44.84 mpg Imp. 44.84
# 12.0
# 10.4
# 14.2
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# 21.1
# 20.6
# 4.2
# 15.7
# 14.4
# 14.5
# 11.3
# 15.6
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# 13.8
# 13.4
# 9.8
# 8.8
# enter 30.70 mpg Imp.
# enter 30.70 mpg Imp. 30.7
# 9.2
# 10.3
# 10.6
# 11.3
# 21.0
# 16.5
# 20.1
# enter 13.58 mpg Imp.
# enter 13.58 mpg Imp. 13.58
# 11.4
# 17.2
# 15.4
# 12.5
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# 11.0
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# enter 33.63 mpg Imp.
# enter 33.63 mpg Imp. 33.63
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 8.1
# 17.2
# 10.1
# 8.6
# 16.8
# 20.5
# 12.0
# 13.2
# 10.3
# 10.4
# 12.9
# enter 15.27 mpg Imp.
# enter 15.27 mpg Imp. 15.27
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 11.5
# 12.1
# 15.0
# 4.7
# 17.2
# 13.6
# 10.7
# 11.9
# 15.7
# 18.1
# 12.3
# 5.1
# 4.2
# enter 27.16 mpg Imp.
# enter 27.16 mpg Imp. 27.16
# 11.4
# 11.0
# 15.5
# 13.7
# 14.6
# 11.4
# 8.8
# enter 19.48 mpg Imp.
# enter 19.48 mpg Imp. 19.48
# 18.1
# 15.5
# 17.7
# 10.6
# 10.8
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 5.3
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 9.9
# 8.2
# 11.5
# 18.8
# 7.7
# 11.5
# 17.4
# 9.0
# 24.3
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 13.5
# 7.6
# enter 26.40 mpg Imp.
# enter 26.40 mpg Imp. 26.4
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 10.2
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# enter 14.79 mpg Imp.
# enter 14.79 mpg Imp. 14.79
# 14.9
# 10.4
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 9.0
# 10.6
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 4.3
# 9.0
# 17.4
# 10.3
# 11.1
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# 12.8
# 19.7
# 9.1
# 16.7
# 11.5
# enter 37.66 mpg Imp.
# enter 37.66 mpg Imp. 37.66
# 19.1
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 8.8
# 13.2
# 12.2
# 9.0
# 28.6
# enter 22.60 mpg Imp.
# enter 22.60 mpg Imp. 22.6
# 18.1
# 4.8
# 11.8
# 14.0
# 16.1
# 18.3
# 10.4
# 11.9
# 10.7
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 13.7
# 15.1
# 14.7
# 9.7
# 16.3
# 11.6
# 11.0
# 5.4
# 6.0
# 9.0
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 7.1
# 13.7
# 13.9
# 17.0
# enter 15.35 mpg Imp.
# enter 15.35 mpg Imp. 15.35
# 10.2
# 7.6
# 8.6
# 10.9
# 12.3
# 16.0
# 10.3
# enter 21.73 mpg Imp.
# enter 21.73 mpg Imp. 21.73
# 10.9
# enter 19.09 mpg Imp.
# enter 19.09 mpg Imp. 19.09
# 18.9
# 11.5
# 18.7
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 18.4
# 13.6
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# 10.5
# 8.9
# 17.6
# 15.6
# 14.8
# 10.1
# 11.6
# enter 23.54 mpg Imp.
# enter 23.54 mpg Imp. 23.54
# 10.9
# 16.8
# 21.0
# enter 20.32 mpg Imp.
# enter 20.32 mpg Imp. 20.32
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 11.1
# 9.8
# 20.3
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 12.0
# 10.2
# 14.7
# 12.7
# enter 13.58 mpg Imp.
# enter 13.58 mpg Imp. 13.58
# 10.9
# 4.2
# 12.5
# 10.3
# 11.0
# 11.9
# 9.6
# 16.2
# 7.9
# 11.0
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 13.2
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 16.4
# 11.3
# 10.9
# 8.2
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 9.7
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# 11.5
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# 17.4
# 14.3
# enter 25.00 mpg Imp.
# enter 25.00 mpg Imp. 25.0
# enter 49.56 mpg Imp.
# enter 49.56 mpg Imp. 49.56
# 14.5
# 20.2
# 11.5
# 8.9
# 8.8
# 11.5
# enter 11.08 mpg Imp.
# enter 11.08 mpg Imp. 11.08
# 18.1
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 8.7
# 11.9
# 21.0
# 9.8
# 10.4
# 4.5
# enter 52.31 mpg Imp.
# enter 52.31 mpg Imp. 52.31
# enter 13.65 mpg Imp.
# enter 13.65 mpg Imp. 13.65
# 13.0
# 4.2
# enter 14.95 mpg Imp.
# enter 14.95 mpg Imp. 14.95
# 9.6
# 21.0
# 16.3
# 9.7
# 12.3
# enter 37.66 mpg Imp.
# enter 37.66 mpg Imp. 37.66
# 13.1
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 10.0
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 12.3
# 9.8
# 10.8
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# 19.1
# 13.5
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# 9.6
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 4.2
# 9.8
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 11.8
# 8.6
# 12.8
# 10.8
# 13.9
# 13.8
# 11.9
# enter 13.32 mpg Imp.
# enter 13.32 mpg Imp. 13.32
# 18.8
# 20.5
# 15.7
# 17.4
# 16.2
# 17.0
# 12.8
# 10.8
# 8.2
# 10.9
# enter 19.09 mpg Imp.
# enter 19.09 mpg Imp. 19.09
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 11.6
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 10.6
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# enter 15.78 mpg Imp.
# enter 15.78 mpg Imp. 15.78
# 6.9
# 7.2
# enter 14.79 mpg Imp.
# enter 14.79 mpg Imp. 14.79
# 17.9
# 9.2
# 10.3
# 22.4
# 17.4
# 9.3
# 10.9
# 12.0
# 9.8
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# 4.2
# 12.0
# 8.8
# 10.2
# 18.1
# 8.6
# 10.5
# 11.8
# enter 26.16 mpg Imp.
# enter 26.16 mpg Imp. 26.16
# 7.4
# 13.0
# 18.1
# 9.7
# 11.6
# 14.6
# 8.6
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# 8.7
# 10.6
# 10.9
# enter 13.98 mpg Imp.
# enter 13.98 mpg Imp. 13.98
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# 10.5
# 9.3
# 16.8
# 8.9
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 10.6
# 10.1
# 10.4
# 9.1
# 16.7
# 12.4
# enter 20.92 mpg Imp.
# enter 20.92 mpg Imp. 20.92
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# 10.8
# enter 15.19 mpg Imp.
# enter 15.19 mpg Imp. 15.19
# 10.8
# 17.7
# 11.7
# 13.8
# 14.2
# enter 33.23 mpg Imp.
# enter 33.23 mpg Imp. 33.23
# enter 13.65 mpg Imp.
# enter 13.65 mpg Imp. 13.65
# 13.0
# 16.7
# 16.3
# 16.0
# 8.3
# enter 23.94 mpg Imp.
# enter 23.94 mpg Imp. 23.94
# 8.5
# enter 14.20 mpg Imp.
# enter 14.20 mpg Imp. 14.2
# 17.0
# 12.5
# 10.1
# 15.5
# 11.9
# 11.8
# 12.0
# 12.8
# enter 13.26 mpg Imp.
# enter 13.26 mpg Imp. 13.26
# 8.7
# 21.8
# 10.8
# 10.3
# 11.8
# 12.5
# 13.0
# 18.4
# 13.7
# 5.8
# 18.3
# 17.3
# 15.0
# 7.7
# 9.6
# 14.2
# 11.0
# 22.9
# 12.1
# 17.4
# 10.9
# 9.5
# 9.0
# 12.0
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 23.0
# 12.5
# 8.9
# enter 22.24 mpg Imp.
# enter 22.24 mpg Imp. 22.24
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# 5.5
# 14.8
# 13.2
# 11.8
# 16.7
# 9.0
# enter 22.07 mpg Imp.
# enter 22.07 mpg Imp. 22.07
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# 9.2
# 21.3
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 11.8
# 14.2
# 10.7
# 10.8
# 16.5
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# enter 11.03 mpg Imp.
# enter 11.03 mpg Imp. 11.03
# 8.9
# 8.7
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# 12.0
# 12.5
# 11.9
# enter 13.08 mpg Imp.
# enter 13.08 mpg Imp. 13.08
# 10.6
# 19.6
# 17.2
# 9.1
# 14.6
# 4.6
# enter 24.78 mpg Imp.
# enter 24.78 mpg Imp. 24.78
# 4.2
# 14.3
# 13.2
# 8.6
# 16.7
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 10.6
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# 10.1
# 23.2
# 15.3
# enter 16.42 mpg Imp.
# enter 16.42 mpg Imp. 16.42
# 15.3
# 8.7
# 8.0
# 17.4
# 12.7
# 17.7
# 17.2
# 18.0
# 13.0
# 10.4
# 10.4
# 11.6
# 14.2
# 11.1
# 14.2
# 12.2
# 10.7
# enter 31.39 mpg Imp.
# enter 31.39 mpg Imp. 31.39
# 10.7
# 8.8
# 16.9
# enter 19.48 mpg Imp.
# enter 19.48 mpg Imp. 19.48
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# 10.6
# 10.4
# 14.4
# 9.5
# 14.9
# 11.8
# 4.3
# 16.4
# 5.2
# 10.4
# 11.3
# 17.1
# 18.8
# enter 37.17 mpg Imp.
# enter 37.17 mpg Imp. 37.17
# 12.3
# 10.5
# 10.9
# 14.4
# 11.2
# 4.2
# 16.1
# 15.4
# 8.5
# 12.4
# enter 28.53 mpg Imp.
# enter 28.53 mpg Imp. 28.53
# 13.0
# 21.9
# 9.6
# 20.8
# 10.7
# enter 20.92 mpg Imp.
# enter 20.92 mpg Imp. 20.92
# enter 29.73 mpg Imp.
# enter 29.73 mpg Imp. 29.73
# 10.3
# 12.5
# 4.2
# enter 16.23 mpg Imp.
# enter 16.23 mpg Imp. 16.23
# 9.4
# 12.9
# 17.5
# 9.2
# 10.5
# enter 26.65 mpg Imp.
# enter 26.65 mpg Imp. 26.65
# 12.5
# 14.5
# 13.1
# enter 25.68 mpg Imp.
# enter 25.68 mpg Imp. 25.68
# 13.1
# 11.1
# 14.3
# enter 27.97 mpg Imp.
# enter 27.97 mpg Imp. 27.97
# 17.9
# 10.4
# 11.1
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# enter 24.56 mpg Imp.
# enter 24.56 mpg Imp. 24.56
# enter 67.26 mpg Imp.
# enter 67.26 mpg Imp. 67.26
# 20.2
# 12.1
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 15.1
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# 16.6
# enter 47.08 mpg Imp.
# enter 47.08 mpg Imp. 47.08
# 14.5
# 8.2
# enter 19.22 mpg Imp.
# enter 19.22 mpg Imp. 19.22
# enter 22.97 mpg Imp.
# enter 22.97 mpg Imp. 22.97
# 9.7
# 15.8
# 8.6
# 11.2
# enter 18.83 mpg Imp.
# enter 18.83 mpg Imp. 18.83
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# 8.9
# 14.1
# 10.8
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 11.1
# 8.6
# 12.5
# enter 16.81 mpg Imp.
# enter 16.81 mpg Imp. 16.81
# 22.7
# enter 34.87 mpg Imp.
# enter 34.87 mpg Imp. 34.87
# enter 17.12 mpg Imp.
# enter 17.12 mpg Imp. 17.12
# 10.3
# 9.8
# 11.6
# 17.3
# enter 13.52 mpg Imp.
# enter 13.52 mpg Imp. 13.52
# 9.9
# 16.5
# 8.5
# 9.6
# enter 24.35 mpg Imp.
# enter 24.35 mpg Imp. 24.35
# enter 21.40 mpg Imp.
# enter 21.40 mpg Imp. 21.4
# 19.4
# 15.6
# enter 30.37 mpg Imp.
# enter 30.37 mpg Imp. 30.37
# enter 25.22 mpg Imp.
# enter 25.22 mpg Imp. 25.22
# 4.2
# 11.1
# enter 14.41 mpg Imp.
# enter 14.41 mpg Imp. 14.41
# 9.1
# 11.3
# 15.9
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# enter 26.90 mpg Imp.
# enter 26.90 mpg Imp. 26.9
# 15.2
# 8.6
# 9.1
# 12.7
# 10.9
# 10.5
# 16.3
# 6.8
# 13.1
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# 10.9
# 8.6
# 16.3
# 23.9
# enter 34.03 mpg Imp.
# enter 34.03 mpg Imp. 34.03
# 11.6
# 8.9
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 10.7
# 12.5
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 10.6
# 12.6
# 10.4
# 12.1
# 10.0
# enter 20.62 mpg Imp.
# enter 20.62 mpg Imp. 20.62
# 8.8
# enter 23.35 mpg Imp.
# enter 23.35 mpg Imp. 23.35
# enter 17.22 mpg Imp.
# enter 17.22 mpg Imp. 17.22
# enter 19.75 mpg Imp.
# enter 19.75 mpg Imp. 19.75
# 10.7
# enter 18.46 mpg Imp.
# enter 18.46 mpg Imp. 18.46
# 5.1
# 18.1
# 11.4
# 16.2
# 11.7
# 9.3
# 15.3
# 8.1
# 8.0
# enter 17.88 mpg Imp.
# enter 17.88 mpg Imp. 17.88
# 11.0
# enter 29.12 mpg Imp.
# enter 29.12 mpg Imp. 29.12
# 17.1
# 9.9
# 13.2
# 10.2
# enter 23.15 mpg Imp.
# enter 23.15 mpg Imp. 23.15
# 26.7
# 11.2
# enter 29.43 mpg Imp.
# enter 29.43 mpg Imp. 29.43
# enter 17.99 mpg Imp.
# enter 17.99 mpg Imp. 17.99
# 15.4
# 17.9
# 15.9
# 11.0
# 4.9
# 10.7
# 19.5
# 9.8
# 8.9
# 10.0
# enter 18.34 mpg Imp.
# enter 18.34 mpg Imp. 18.34
# 5.5
# 18.2
# 16.0
# 13.2
# 12.0
# 14.7
# 16.4
# 8.8
# 12.3
# 10.2
# 14.9
# enter 13.98 mpg Imp.
# enter 13.98 mpg Imp. 13.98
# 10.8
# 11.6
# 10.6
# 16.2
# 8.2
# 9.7
# enter 30.05 mpg Imp.
# enter 30.05 mpg Imp. 30.05
# 8.8
# 13.5
# enter 28.25 mpg Imp.
# ...
# 19.39
# 12.57
# 8.59
# enter 22.31 mpg Imp.
# enter 22.31 mpg Imp. 22.31
# 13.88
# 9.61
# 10.87
# 9.48
# 12.67
# 9.22
# 13.24
# 9.03
# 9.77
# 11.26
# enter 28.52 mpg Imp.
# enter 28.52 mpg Imp. 28.52
# enter 19.58 mpg Imp.
# enter 19.58 mpg Imp. 19.58
# 8.6
# enter 21.54 mpg Imp.
# enter 21.54 mpg Imp. 21.54
# 16.73
# enter 35.20 mpg Imp.
# enter 35.20 mpg Imp. 35.2
# 10.29
# 9.95
# 12.86
# 8.14
# 12.69
# enter 18.79 mpg Imp.
# enter 18.79 mpg Imp. 18.79
# 11.35
# 10.43
# enter 30.04 mpg Imp.
# enter 30.04 mpg Imp. 30.04
# 7.96
# 9.98
# 10.99
# enter 25.63 mpg Imp.
# enter 25.63 mpg Imp. 25.63
# 15.12
# enter 24.99 mpg Imp.
# enter 24.99 mpg Imp. 24.99
# enter 21.55 mpg Imp.
# enter 21.55 mpg Imp. 21.55
# 8.57
# 8.71
# enter 21.62 mpg Imp.
# enter 21.62 mpg Imp. 21.62
# 12.95
# 10.62
# enter 28.99 mpg Imp.
# enter 28.99 mpg Imp. 28.99
# 11.73
# 13.37
# 9.15
# enter 19.11 mpg Imp.
# enter 19.11 mpg Imp. 19.11
# 14.54
# 8.34
# 10.41
# 10.51
# 6.04
# 9.64
# 11.81
# enter 18.55 mpg Imp.
# enter 18.55 mpg Imp. 18.55
# 10.93
# 12.2
# 16.66
# 10.02
# enter 19.62 mpg Imp.
# enter 19.62 mpg Imp. 19.62
# enter 26.25 mpg Imp.
# enter 26.25 mpg Imp. 26.25
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# 8.15
# 13.46
# 14.64
# 8.95
# enter 30.62 mpg Imp.
# enter 30.62 mpg Imp. 30.62
# enter 31.21 mpg Imp.
# enter 31.21 mpg Imp. 31.21
# 12.16
# 8.97
# 8.24
# 5.68
# 8.48
# 10.53
# enter 30.72 mpg Imp.
# enter 30.72 mpg Imp. 30.72
# enter 24.30 mpg Imp.
# enter 24.30 mpg Imp. 24.3
# 9.56
# 14.4
# 18.69
# 11.12
# 15.46
# 10.45
# enter 26.99 mpg Imp.
# enter 26.99 mpg Imp. 26.99
# enter 37.46 mpg Imp.
# enter 37.46 mpg Imp. 37.46
# 10.02
# enter 33.14 mpg Imp.
# enter 33.14 mpg Imp. 33.14
# 5.74
# 11.39
# 8.69
# enter 50.09 mpg Imp.
# enter 50.09 mpg Imp. 50.09
# 12.55
# 8.08
# 9.76
# 15.41
# 8.52
# 10.21
# 10.71
# 8.48
# 15.51
# enter 28.35 mpg Imp.
# enter 28.35 mpg Imp. 28.35
# enter 24.99 mpg Imp.
# enter 24.99 mpg Imp. 24.99
# 8.47
# 7.81
# 8.72
# enter 27.78 mpg Imp.
# enter 27.78 mpg Imp. 27.78
# 9.98
# 14.19
# 9.16
# 12.51
# 10.58
# 10.42
# 18.09
# 13.01
# 4.96
# 18.01
# 9.96
# 10.58
# 12.48
# 10.02
# 13.22
# enter 20.53 mpg Imp.
# enter 20.53 mpg Imp. 20.53
# enter 32.90 mpg Imp.
# enter 32.90 mpg Imp. 32.9
# 13.94
# 8.78
# enter 35.49 mpg Imp.
# enter 35.49 mpg Imp. 35.49
# 11.3
# enter 24.40 mpg Imp.
# enter 24.40 mpg Imp. 24.4
# 10.34
# 12.18
# enter 29.81 mpg Imp.
# enter 29.81 mpg Imp. 29.81
# 7.09
# 10.23
# 9.6
# 12.85
# enter 57.07 mpg Imp.
# enter 57.07 mpg Imp. 57.07
# 13.38
# 8.63
# 16.32
# enter 32.15 mpg Imp.
# enter 32.15 mpg Imp. 32.15
# enter 27.61 mpg Imp.
# enter 27.61 mpg Imp. 27.61
# enter 14.58 mpg Imp.
# enter 14.58 mpg Imp. 14.58
# 14.71
# 13.9
# 13.09
# 8.01
# enter 19.96 mpg Imp.
# enter 19.96 mpg Imp. 19.96
# 10.57
# 13.38
# 13.61
# 11.13
# 10.76
# 9.63
# 8.75
# 7.75
# enter 22.16 mpg Imp.
# enter 22.16 mpg Imp. 22.16
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# enter 16.98 mpg Imp.
# enter 16.98 mpg Imp. 16.98
# 7.75
# 12.61
# enter 20.93 mpg Imp.
# enter 20.93 mpg Imp. 20.93
# 12.9
# enter 30.67 mpg Imp.
# enter 30.67 mpg Imp. 30.67
# enter 21.61 mpg Imp.
# enter 21.61 mpg Imp. 21.61
# enter 36.15 mpg Imp.
# enter 36.15 mpg Imp. 36.15
# enter 28.15 mpg Imp.
# enter 28.15 mpg Imp. 28.15
# enter 28.82 mpg Imp.
# enter 28.82 mpg Imp. 28.82
# 10.12
# enter 27.02 mpg Imp.
# enter 27.02 mpg Imp. 27.02
# 15.21
# 9.06
# 8.15
# enter 37.24 mpg Imp.
# enter 37.24 mpg Imp. 37.24
# 11.47
# 11.01
# 8.14
# 12.88
# 18.24
# 11.66
# enter 17.74 mpg Imp.
# enter 17.74 mpg Imp. 17.74
# 14.04
# 14.03
# 10.58
# 9.54
# 13.56
# 8.22
# 12.27
# 12.42
# 11.07
# 9.98
# enter 21.45 mpg Imp.
# enter 21.45 mpg Imp. 21.45
# 13.47
# 15.56
# enter 25.77 mpg Imp.
# enter 25.77 mpg Imp. 25.77
# enter 36.24 mpg Imp.
# enter 36.24 mpg Imp. 36.24
# enter 26.56 mpg Imp.
# enter 26.56 mpg Imp. 26.56
# 9.86
# 9.41
# enter 32.19 mpg Imp.
# enter 32.19 mpg Imp. 32.19
# 5.68
# 12.31
# 8.69
# enter 21.65 mpg Imp.
# enter 21.65 mpg Imp. 21.65
# 9.94
# 10.66
# 9.68
# enter 17.00 mpg Imp.
# enter 17.00 mpg Imp. 17.0
# 14.74
# enter 32.98 mpg Imp.
# enter 32.98 mpg Imp. 32.98
# 9.19
# 10.06
# 8.46
# 10.39
# 11.78
# 11.54
# 7.84
# 11.45
# enter 27.44 mpg Imp.
# enter 27.44 mpg Imp. 27.44
# enter 29.92 mpg Imp.
# enter 29.92 mpg Imp. 29.92
# 13.96
# 9.15
# 11.77
# 13.96
# 8.07
# 9.81
# enter 24.14 mpg Imp.
# enter 24.14 mpg Imp. 24.14
# enter 19.82 mpg Imp.
# enter 19.82 mpg Imp. 19.82
# 8.29
# 10.88
# 8.57
# enter 32.68 mpg Imp.
# enter 32.68 mpg Imp. 32.68
# 9.62
# 13.51
# enter 23.70 mpg Imp.
# enter 23.70 mpg Imp. 23.7
# 18.2
# 16.41
# 8.71
# 9.89
# 6.42
# 10.13
# 14.07
# 7.46
# enter 30.56 mpg Imp.
# enter 30.56 mpg Imp. 30.56
# 16.59
# enter 20.93 mpg Imp.
# enter 20.93 mpg Imp. 20.93
# 7.84
# 10.9
# 20.23
# 13.26
# 10.71
# 8.71
# 8.94
# enter 19.46 mpg Imp.
# enter 19.46 mpg Imp. 19.46
# 16.5
# 9.72
# 10.56
# 12.09
# 9.26
# 14.36
# 10.11
# 9.39
# enter 28.32 mpg Imp.
# enter 28.32 mpg Imp. 28.32
# 11.28
# 9.37
# 14.29
# enter 25.49 mpg Imp.
# enter 25.49 mpg Imp. 25.49
# 13.16
# 14.93
# enter 24.86 mpg Imp.
# enter 24.86 mpg Imp. 24.86
# 13.13
# 9.7
# 9.66
# enter 19.66 mpg Imp.
# enter 19.66 mpg Imp. 19.66
# enter 33.67 mpg Imp.
# enter 33.67 mpg Imp. 33.67
# enter 25.60 mpg Imp.
# enter 25.60 mpg Imp. 25.6
# enter 27.67 mpg Imp.
# enter 27.67 mpg Imp. 27.67
# 12.01
# 9.9
# 11.05
# enter 27.78 mpg Imp.
# enter 27.78 mpg Imp. 27.78
# 13.65
# 12.3
# 6.25
# 13.96
# 12.31
# 8.22
# enter 28.11 mpg Imp.
# enter 28.11 mpg Imp. 28.11
# 14.54
# 12.64
# 14.14
# 8.88
# 10.89
# enter 20.11 mpg Imp.
# enter 20.11 mpg Imp. 20.11
# 8.98
# 8.53
# 10.13
# 8.46
# 8.84
# 13.86
# enter 17.04 mpg Imp.
# enter 17.04 mpg Imp. 17.04
# 9.28
# 9.39
# 7.84
# enter 26.83 mpg Imp.
# enter 26.83 mpg Imp. 26.83
# enter 51.31 mpg Imp.
# enter 51.31 mpg Imp. 51.31
# 11.7
# 14.02
# enter 18.72 mpg Imp.
# enter 18.72 mpg Imp. 18.72
# 13.05
# 15.93
# 15.87
# enter 16.71 mpg Imp.
# enter 16.71 mpg Imp. 16.71
# enter 31.76 mpg Imp.
# enter 31.76 mpg Imp. 31.76
# 10.1
# 9.03
# 9.06
# 8.33
# 10.62
# enter 31.30 mpg Imp.
# enter 31.30 mpg Imp. 31.3
# 8.32
# enter 27.84 mpg Imp.
# enter 27.84 mpg Imp. 27.84
# 8.19
# enter 27.65 mpg Imp.
# enter 27.65 mpg Imp. 27.65
# 13.99
# enter 21.65 mpg Imp.
# enter 21.65 mpg Imp. 21.65
# 10.7
# enter 39.51 mpg Imp.
# enter 39.51 mpg Imp. 39.51
# 14.6
# 13.06
# enter 23.38 mpg Imp.
# enter 23.38 mpg Imp. 23.38
# 8.81
# 9.89
# 5.5
# enter 34.32 mpg Imp.
# enter 34.32 mpg Imp. 34.32
# 12.94
# 9.15
# 8.3
# 9.29
# 10.62
# 13.08
# enter 28.66 mpg Imp.
# enter 28.66 mpg Imp. 28.66
# 10.56
# 10.65
# enter 25.45 mpg Imp.
# enter 25.45 mpg Imp. 25.45
# 9.46
# 10.19
# enter 33.08 mpg Imp.
# enter 33.08 mpg Imp. 33.08
# 9.04
# 8.68
# 7.61
# 12.4
# enter 36.52 mpg Imp.
# enter 36.52 mpg Imp. 36.52
# 12.55
# 12.23
# 9.1
# 9.9
# enter 34.22 mpg Imp.
# enter 34.22 mpg Imp. 34.22
# 13.05
# enter 19.94 mpg Imp.
# enter 19.94 mpg Imp. 19.94
# 11.0
# 8.59
# enter 15.15 mpg Imp.
# enter 15.15 mpg Imp. 15.15
# 10.97
# 13.31
# 13.21
# enter 28.29 mpg Imp.
# enter 28.29 mpg Imp. 28.29
# enter 31.09 mpg Imp.
# enter 31.09 mpg Imp. 31.09
# 9.98
# 17.29
# 14.26
# 12.49
# enter 34.58 mpg Imp.
# enter 34.58 mpg Imp. 34.58
# 5.05
# 13.39
# 19.16
# 15.67
# 7.77
# 5.71
# enter 15.87 mpg Imp.
# enter 15.87 mpg Imp. 15.87
# 13.73
# enter 53.50 mpg Imp.
# enter 53.50 mpg Imp. 53.5
# 16.83
# 9.1
# 9.77
# enter 27.82 mpg Imp.
# enter 27.82 mpg Imp. 27.82
# enter 31.63 mpg Imp.
# enter 31.63 mpg Imp. 31.63
# enter 32.85 mpg Imp.
# enter 32.85 mpg Imp. 32.85
# 10.82
# 7.41
# 11.43
# 18.07
# enter 23.64 mpg Imp.
# enter 23.64 mpg Imp. 23.64
# 9.66
# 11.84
# 16.06
# 11.68
# 9.16
# 10.57
# 12.69
# 17.38
# 11.9
# 8.74
# 9.92
# 7.96
# 9.9
# enter 27.90 mpg Imp.
# enter 27.90 mpg Imp. 27.9
# 9.23
# 10.9
# 7.89
# 13.54
# 9.92
# 17.96
# enter 27.57 mpg Imp.
# enter 27.57 mpg Imp. 27.57
# 9.88
# 16.98
# enter 32.32 mpg Imp.
# enter 32.32 mpg Imp. 32.32
# 11.0
# 15.89
# enter 18.11 mpg Imp.
# enter 18.11 mpg Imp. 18.11
# 12.75
# 16.52
# 13.27
# 10.71
# 9.62
# 12.7
# 14.15
# 14.38
# enter 27.74 mpg Imp.
# enter 27.74 mpg Imp. 27.74
# enter 31.95 mpg Imp.
# enter 31.95 mpg Imp. 31.95
# 10.78
# 8.74
# 9.27
# enter 34.92 mpg Imp.
# enter 34.92 mpg Imp. 34.92
# enter 31.58 mpg Imp.
# enter 31.58 mpg Imp. 31.58
# 8.13
# 8.74
# 8.27
# enter 19.99 mpg Imp.
# enter 19.99 mpg Imp. 19.99
# 7.07
# enter 33.79 mpg Imp.
# enter 33.79 mpg Imp. 33.79
# 11.47
# enter 22.84 mpg Imp.
# enter 22.84 mpg Imp. 22.84
# enter 34.26 mpg Imp.
# enter 34.26 mpg Imp. 34.26
# 12.94
# 14.46
# 9.88
# enter 29.23 mpg Imp.
# enter 29.23 mpg Imp. 29.23
# enter 29.84 mpg Imp.
# enter 29.84 mpg Imp. 29.84
# enter 20.35 mpg Imp.
# enter 20.35 mpg Imp. 20.35
# 11.01
# enter 20.03 mpg Imp.
# enter 20.03 mpg Imp. 20.03
# enter 21.64 mpg Imp.
# enter 21.64 mpg Imp. 21.64
# 9.47
# enter 31.33 mpg Imp.
# enter 31.33 mpg Imp. 31.33
# enter 22.52 mpg Imp.
# enter 22.52 mpg Imp. 22.52
# 8.61
# 9.93
# enter 27.86 mpg Imp.
# enter 27.86 mpg Imp. 27.86
# 8.34
# 9.64
# 11.01
# 13.35
# 6.18
# 8.63
# 15.79
# 15.61
# enter 30.51 mpg Imp.
# enter 30.51 mpg Imp. 30.51
# 11.97
# 10.38
# 9.48
# 14.95
# 10.15
# 8.54
# enter 35.29 mpg Imp.
# enter 35.29 mpg Imp. 35.29
# enter 51.74 mpg Imp.
# enter 51.74 mpg Imp. 51.74
# 16.6
# enter 21.80 mpg Imp.
# enter 21.80 mpg Imp. 21.8
# 11.85
# enter 28.72 mpg Imp.
# enter 28.72 mpg Imp. 28.72
# enter 17.39 mpg Imp.
# enter 17.39 mpg Imp. 17.39
# 10.15
# enter 33.43 mpg Imp.
# enter 33.43 mpg Imp. 33.43
# 11.55
# 15.31
# 7.83
# 9.8
# enter 26.35 mpg Imp.
# enter 26.35 mpg Imp. 26.35
# 12.04
# 9.06
# 11.45
# 10.96
# enter 28.84 mpg Imp.
# enter 28.84 mpg Imp. 28.84
# 9.06
# enter 36.81 mpg Imp.
# enter 36.81 mpg Imp. 36.81
# 12.62
# 9.36
# 15.94
# 17.19
# 7.46
# 9.02
# 7.82
# 9.46
# 15.15
# 10.63
# 10.52
# 11.5
# 6.5
# 8.95
# enter 26.62 mpg Imp.
# enter 26.62 mpg Imp. 26.62
# enter 29.32 mpg Imp.
# enter 29.32 mpg Imp. 29.32
# 12.62
# 10.3
# enter 35.40 mpg Imp.
# enter 35.40 mpg Imp. 35.4
# enter 26.25 mpg Imp.
# enter 26.25 mpg Imp. 26.25
# 10.69
# 10.87
# 8.78
# enter 13.24 mpg Imp.
# enter 13.24 mpg Imp. 13.24
# 10.55
# 8.03
# 14.0
# 11.09
# 8.5
# 11.47
# enter 26.04 mpg Imp.
# enter 26.04 mpg Imp. 26.04
# 9.63
# 13.06
# enter 32.27 mpg Imp.
# enter 32.27 mpg Imp. 32.27
# 8.73
# 14.66
# enter 21.78 mpg Imp.
# enter 21.78 mpg Imp. 21.78
# 14.37
# 8.54
# enter 14.66 mpg Imp.
# enter 14.66 mpg Imp. 14.66
# enter 26.85 mpg Imp.
# enter 26.85 mpg Imp. 26.85
# 5.55
# enter 22.13 mpg Imp.
# enter 22.13 mpg Imp. 22.13
# 8.58
# 12.31
# 8.14
# enter 17.70 mpg Imp.
# enter 17.70 mpg Imp. 17.7
# 15.57
# 8.44
# 12.7
# 10.87
# 14.16
# 11.35
# 10.05
# 11.11
# 15.41
# 9.9
# 11.39
# 5.71
# 8.78
# 10.0
# 7.92
# 12.73
# 10.98
# 9.64
# 10.0
# 9.94
# 15.77
# 9.1
# enter 21.61 mpg Imp.
# enter 21.61 mpg Imp. 21.61
# enter 19.23 mpg Imp.
# enter 19.23 mpg Imp. 19.23
# 10.71
# 6.28
# 9.48
# 8.63
# 9.43
# 8.47
# enter 20.84 mpg Imp.
# enter 20.84 mpg Imp. 20.84
# 9.97
# 10.69
# 9.09
# 10.36
# 8.23
# 13.87
# 8.7
# enter 30.82 mpg Imp.
# enter 30.82 mpg Imp. 30.82
# 9.51
# 13.54
# 13.61
# 11.99
# 12.8
# enter 18.62 mpg Imp.
# enter 18.62 mpg Imp. 18.62
# 8.59
# 12.29
# 7.62
# 14.71
# enter 33.16 mpg Imp.
# enter 33.16 mpg Imp. 33.16
# 9.22
# 16.64
# 8.41
# 9.86
# enter 29.49 mpg Imp.
# enter 29.49 mpg Imp. 29.49
# 10.01
# 9.61
# enter 39.10 mpg Imp.
# enter 39.10 mpg Imp. 39.1
# 12.49
# enter 24.88 mpg Imp.
# enter 24.88 mpg Imp. 24.88
# 8.77
# enter 20.81 mpg Imp.
# enter 20.81 mpg Imp. 20.81
# enter 22.23 mpg Imp.
# enter 22.23 mpg Imp. 22.23
# 14.35
# enter 30.28 mpg Imp.
# enter 30.28 mpg Imp. 30.28
# 8.27
# 13.42
# 9.95
# enter 29.67 mpg Imp.
# enter 29.67 mpg Imp. 29.67
# 15.84
# 14.22
# 10.04
# enter 24.84 mpg Imp.
# enter 24.84 mpg Imp. 24.84
# 7.85
# 9.51
# 13.48
# 10.28
# 14.13
# 8.68
# enter 20.37 mpg Imp.
# enter 20.37 mpg Imp. 20.37
# 10.97
# 11.29
# enter 22.13 mpg Imp.
# enter 22.13 mpg Imp. 22.13
# 12.31
# enter 34.37 mpg Imp.
# enter 34.37 mpg Imp. 34.37
# enter 17.19 mpg Imp.
# enter 17.19 mpg Imp. 17.19
# 10.81
# 8.63
# 8.71
# 10.68
# 8.85
# 13.55
# 5.67
# 14.61
# 12.87
# 7.92
# 8.75
# enter 24.86 mpg Imp.
# enter 24.86 mpg Imp. 24.86
# 8.58
# 9.1
# enter 16.37 mpg Imp.
# enter 16.37 mpg Imp. 16.37
# 14.77
# 18.64
# 9.9
# 7.3
# 7.41
# enter 23.01 mpg Imp.
# enter 23.01 mpg Imp. 23.01
# 7.89
# enter 26.46 mpg Imp.
# enter 26.46 mpg Imp. 26.46
# enter 23.73 mpg Imp.
# enter 23.73 mpg Imp. 23.73
# enter 21.43 mpg Imp.
# enter 21.43 mpg Imp. 21.43
# 11.1
# 7.54
# 5.55
# 8.79
# 9.71
# 9.98
# 9.49
# 10.26
# 14.51
# 7.03
# 15.04
# enter 35.69 mpg Imp.
# enter 35.69 mpg Imp. 35.69
# 9.26
# 7.94
# enter 33.41 mpg Imp.
# enter 33.41 mpg Imp. 33.41
# 9.34
# enter 21.75 mpg Imp.
# enter 21.75 mpg Imp. 21.75
# 10.69
# enter 23.07 mpg Imp.
# enter 23.07 mpg Imp. 23.07
# 7.28
# 15.65
# enter 21.96 mpg Imp.
# enter 21.96 mpg Imp. 21.96
# 16.07
# enter 20.58 mpg Imp.
# enter 20.58 mpg Imp. 20.58
# 11.64
# enter 35.85 mpg Imp.
# enter 35.85 mpg Imp. 35.85
# enter 16.43 mpg Imp.
# enter 16.43 mpg Imp. 16.43
# 13.81
# 12.63
# 14.3
# enter 21.44 mpg Imp.
# enter 21.44 mpg Imp. 21.44
# enter 27.84 mpg Imp.
# enter 27.84 mpg Imp. 27.84
# 6.79
# 9.23
# 11.34
# 11.29
# enter 19.37 mpg Imp.
# enter 19.37 mpg Imp. 19.37
# enter 17.67 mpg Imp.
# enter 17.67 mpg Imp. 17.67
# 17.18
# 8.32
# 12.11
# 14.71
# enter 24.04 mpg Imp.
# enter 24.04 mpg Imp. 24.04
# 15.06
# 8.71
# 8.34
# 7.96
# enter 27.72 mpg Imp.
# enter 27.72 mpg Imp. 27.72
# enter 25.52 mpg Imp.
# enter 25.52 mpg Imp. 25.52
# 22.6
# 15.71
# enter 31.74 mpg Imp.
# enter 31.74 mpg Imp. 31.74
# 13.38
# 8.62
# 20.82
# 9.68
# enter 22.67 mpg Imp.
# enter 22.67 mpg Imp. 22.67
# 13.51
# 9.49
# enter 17.63 mpg Imp.
# enter 17.63 mpg Imp. 17.63
# 9.1
# 13.89
# enter 55.39 mpg Imp.
# enter 55.39 mpg Imp. 55.39
# 11.33
# enter 26.00 mpg Imp.
# enter 26.00 mpg Imp. 26.0
# enter 28.36 mpg Imp.
# enter 28.36 mpg Imp. 28.36
# 19.11
# 10.89
# 7.46
# 15.33
# enter 26.17 mpg Imp.
# enter 26.17 mpg Imp. 26.17
# 8.59
# 13.84
# 10.75
# 10.62
# 8.74
# 7.84
# 8.74
# enter 21.59 mpg Imp.
# enter 21.59 mpg Imp. 21.59
# 10.44
# 13.96
# 13.86
# 10.61
# 15.25
# 9.04
# enter 31.72 mpg Imp.
# enter 31.72 mpg Imp. 31.72
# enter 33.55 mpg Imp.
# enter 33.55 mpg Imp. 33.55
# 11.7
# enter 22.23 mpg Imp.
# enter 22.23 mpg Imp. 22.23
# enter 23.16 mpg Imp.
# enter 23.16 mpg Imp. 23.16
# enter 25.29 mpg Imp.
# enter 25.29 mpg Imp. 25.29
# enter 21.97 mpg Imp.
# enter 21.97 mpg Imp. 21.97
# 13.18
# 7.21
# enter 17.84 mpg Imp.
# enter 17.84 mpg Imp. 17.84
# 9.37
# 13.26
# enter 18.39 mpg Imp.
# enter 18.39 mpg Imp. 18.39
# enter 29.75 mpg Imp.
# enter 29.75 mpg Imp. 29.75
# enter 32.10 mpg Imp.
# enter 32.10 mpg Imp. 32.1
# 10.41
# enter 16.05 mpg Imp.
# enter 16.05 mpg Imp. 16.05
# 8.54
# 8.66
# 8.54
# 9.36
# 8.62
# enter 12.90 mpg Imp.
# enter 12.90 mpg Imp. 12.9
# 9.94
# enter 34.12 mpg Imp.
# enter 34.12 mpg Imp. 34.12
# 7.88
# 7.51
# 9.29
# 10.36
# 7.79
# enter 20.69 mpg Imp.
# enter 20.69 mpg Imp. 20.69
# 10.13
# enter 32.77 mpg Imp.
# enter 32.77 mpg Imp. 32.77
# 9.89
# 12.26
# 7.42
# 20.4
# enter 34.92 mpg Imp.
# enter 34.92 mpg Imp. 34.92
# 8.2
# 13.93
# enter 17.50 mpg Imp.
# enter 17.50 mpg Imp. 17.5
# 12.99
# 9.11
# 10.6
# 9.53
# 15.0
# 8.8
# 7.67
# 8.89
# enter 30.74 mpg Imp.
# enter 30.74 mpg Imp. 30.74
# 10.61
# 13.21
# 9.25
# enter 27.69 mpg Imp.
# enter 27.69 mpg Imp. 27.69
# 14.12
# 15.71
# 11.59
# 7.71
# 12.49
# 10.4
# 12.68
# 9.67
# 9.27
# 13.71
# 8.81
# enter 35.05 mpg Imp.
# enter 35.05 mpg Imp. 35.05
# 14.31
# enter 30.79 mpg Imp.
# enter 30.79 mpg Imp. 30.79
# 11.25
# 11.13
# 13.29
# 12.9
# 12.94
# 15.49
# 9.48
# 16.64
# 13.01
# 8.21
# 9.73
# 5.19
# enter 25.84 mpg Imp.
# enter 25.84 mpg Imp. 25.84
# 8.17
# 10.89
# enter 25.18 mpg Imp.
# enter 25.18 mpg Imp. 25.18
# 9.21
# 8.88
# 7.58
# 10.09
# 7.6
# enter 21.25 mpg Imp.
# enter 21.25 mpg Imp. 21.25
# enter 33.63 mpg Imp.
# enter 33.63 mpg Imp. 33.63
# 9.3
# 9.82
# 12.13
# 10.48
# 12.17
# enter 21.52 mpg Imp.
# enter 21.52 mpg Imp. 21.52
# 17.3
# 8.85
# 9.68
# enter 20.46 mpg Imp.
# enter 20.46 mpg Imp. 20.46
# enter 33.93 mpg Imp.
# enter 33.93 mpg Imp. 33.93
# 13.13
# 11.78
# 7.97
# enter 31.40 mpg Imp.
# enter 31.40 mpg Imp. 31.4
# 9.79
# 10.94
# 21.55
# enter 19.70 mpg Imp.
# enter 19.70 mpg Imp. 19.7
# 18.52
# enter 30.74 mpg Imp.
# enter 30.74 mpg Imp. 30.74
# 8.07
# enter 36.97 mpg Imp.
# enter 36.97 mpg Imp. 36.97
# 16.0
# enter 24.25 mpg Imp.
# enter 24.25 mpg Imp. 24.25
# 16.02
# 10.12
# 10.35
# 5.33
# 7.43
# enter 25.18 mpg Imp.
# enter 25.18 mpg Imp. 25.18
# 7.44
# enter 22.00 mpg Imp.
# enter 22.00 mpg Imp. 22.0
# 17.44
# 10.11
# 8.21
# 8.91
# enter 20.35 mpg Imp.
# enter 20.35 mpg Imp. 20.35
# 10.55
# 16.95
# 12.55
# 11.87
# 8.29
# 9.88
# 7.32
# enter 17.31 mpg Imp.
# enter 17.31 mpg Imp. 17.31
# enter 30.46 mpg Imp.
# enter 30.46 mpg Imp. 30.46
# enter 29.97 mpg Imp.
# enter 29.97 mpg Imp. 29.97
# 6.72
# 13.96
# 11.28
# 8.45
# 9.15
# 14.64
# 10.04
# 8.8
# 12.4
# 11.41
# 13.46
# 13.13
# enter 34.68 mpg Imp.
# enter 34.68 mpg Imp. 34.68
# 12.61
# 14.16
# 9.18
# enter 20.58 mpg Imp.
# enter 20.58 mpg Imp. 20.58
# 10.05
# enter 30.80 mpg Imp.
# enter 30.80 mpg Imp. 30.8
# 15.19
# enter 27.47 mpg Imp.
# enter 27.47 mpg Imp. 27.47
# 7.18
# 12.89
# enter 29.97 mpg Imp.
# enter 29.97 mpg Imp. 29.97
# enter 29.27 mpg Imp.
# enter 29.27 mpg Imp. 29.27
# 10.8
# 8.96
# 15.72
# 18.73
# 8.28
# 13.26
# enter 26.08 mpg Imp.
# enter 26.08 mpg Imp. 26.08
# enter 20.82 mpg Imp.
# enter 20.82 mpg Imp. 20.82
# 11.05
# 8.36
# 11.27
# enter 23.07 mpg Imp.
# enter 23.07 mpg Imp. 23.07
# 8.84
# 8.82
# 9.53
# 10.89
# 9.91
# 7.52
# 15.24
# 9.43
# 15.99
# enter 29.86 mpg Imp.
# enter 29.86 mpg Imp. 29.86
# 9.02
# 11.47
# 13.74
# 13.11
# 13.66
# 11.54
# 7.42
# 13.75
# 11.48
# enter 32.83 mpg Imp.
# enter 32.83 mpg Imp. 32.83
# 14.28
# 14.66
# enter 25.92 mpg Imp.
# enter 25.92 mpg Imp. 25.92
# enter 30.60 mpg Imp.
# enter 30.60 mpg Imp. 30.6
# enter 29.91 mpg Imp.
# enter 29.91 mpg Imp. 29.91
# 10.01
# 6.92
# enter 29.00 mpg Imp.
# enter 29.00 mpg Imp. 29.0
# 9.71
# 9.77
# enter 21.26 mpg Imp.
# enter 21.26 mpg Imp. 21.26
# 10.46
# 9.88
# enter 23.93 mpg Imp.
# enter 23.93 mpg Imp. 23.93
# 13.15
# 11.4
# 8.54
# 6.67
# enter 23.74 mpg Imp.
# enter 23.74 mpg Imp. 23.74
# 8.11
# 10.96
# 9.38
# 10.64
# 13.81
# 9.58
# 8.64
# 10.77
# 10.07
# 15.07
# 12.88
# 9.88
# 6.17
# 12.47
# 15.15
# 16.73
# 15.63
# 14.52

# %% [markdown]
# ### Step 2: Compute missing values in Fuel Consumption Comb using the formula

# %%
missing_comb_mask = df['Fuel Consumption Comb'].isnull()
df.loc[missing_comb_mask, 'Fuel Consumption Comb'] = 0.55 * df['Fuel Consumption City'] + 0.45 * df['Fuel Consumption Hwy']

# %% [markdown]
# ### Step 3: Fill in missing values in Fuel Consumption City and Fuel Consumption Hwy

# %%
missing_city_mask = df['Fuel Consumption City'].isnull()
missing_hwy_mask = df['Fuel Consumption Hwy'].isnull()

# %% [markdown]
# ### Calculate missing values in Fuel Consumption City and Hwy using Comb and the other known value

# %%
df.loc[missing_city_mask, 'Fuel Consumption City'] = (df.loc[missing_city_mask, 'Fuel Consumption Comb'] - 0.45 * df.loc[missing_city_mask, 'Fuel Consumption Hwy']) / 0.55
df.loc[missing_hwy_mask, 'Fuel Consumption Hwy'] = (df.loc[missing_hwy_mask, 'Fuel Consumption Comb'] - 0.55 * df.loc[missing_hwy_mask, 'Fuel Consumption City']) / 0.45

# %% [markdown]
# ### Drop rows with any remaining NaN values in these columns

# %%
df.dropna(subset=['Fuel Consumption City', 'Fuel Consumption Hwy', 'Fuel Consumption Comb'], inplace=True)

# %%
df.head()
# Out:
#    Id  Make  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 1   2   9.0            9.0             0.0        6.0          14.0
# 2   3  17.0            4.0             2.0        4.0           2.0
# 3   4   1.0           14.0             0.0        8.0           0.0
# 4   5   9.0            4.0             1.8        4.0           1.0
# 5   6  15.0           12.0             2.4        4.0           0.0
#
#    Fuel Type  Fuel Consumption City  Fuel Consumption Hwy  \
# 1        0.0             725.000000             10.309278
# 2        0.0             980.000000              6.077896
# 3        0.0               5.308629              8.547009
# 4        0.0              12.345679              6.577589
# 5        0.0             885.000000          -1059.014045
#
#    Fuel Consumption Comb  CO2 Emissions(g/km)
# 1               8.361204                  325
# 2               7.406001                  170
# 3               6.765900                  362
# 4              12.484395                  180
# 5              10.193680                  216

# %%
df.isnull().sum()
# Out:
# Id                       0
# Make                     0
# Vehicle Class            0
# Engine Size(L)           0
# Cylinders                0
# Transmission             0
# Fuel Type                0
# Fuel Consumption City    0
# Fuel Consumption Hwy     0
# Fuel Consumption Comb    0
# CO2 Emissions(g/km)      0
# dtype: int64
